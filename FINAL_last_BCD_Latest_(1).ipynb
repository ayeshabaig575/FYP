# %% [markdown]
# <a href="https://colab.research.google.com/github/ayeshabaig575/FYP/blob/main/FINAL_last_BCD_Latest_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import all Necessary libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Intially we used PyTorch for preprocessing.
# **Why PyTorch:**
# - Easy: Beginner-friendly and readable.
# - GPU-Compatible
# - Rich Data Augmentation: Built-in tools like random crop, flip, rotation, color jitter — applied efficiently.
# - Seamless with DataLoader: Integrates perfectly with PyTorch DataLoader for batching, shuffling, and real-time augmentations

# %%
import os
import sys
import cv2
import albumentations as A
from glob import glob
import random
import shutil
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import PIL
import torch
import torchvision
from PIL import Image
from torchvision import transforms
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
from tqdm.notebook import tqdm
from collections import Counter
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torchvision
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
torch.backends.cudnn.deterministic = True


import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
print("Platform:", sys.platform)
print("Python version:", sys.version)
print("---")
print("matplotlib version:", matplotlib.__version__)
print("pandas version:", pd.__version__)
print("PIL version:", PIL.__version__)
print("torch version:", torch.__version__)
print("torchvision version:", torchvision.__version__)
# Out:
# Platform: linux
# Python version: 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# ---
# matplotlib version: 3.10.0
# pandas version: 2.2.2
# PIL version: 11.2.1
# torch version: 2.6.0+cu124
# torchvision version: 0.21.0+cu124

# %% [markdown]
# ## Exploring dataset

# %%
# !cd /content/drive/MyDrive/dataset/Dataset_BUSI_with_GT

# %%
 images_dir = "/content/drive/MyDrive/Breast_cancer_segementation/Dataset_BUSI_with_GT"

print("Images:", images_dir)
# Out:
# Images: /content/drive/MyDrive/Breast_cancer_segementation/Dataset_BUSI_with_GT

# %%
classes = os.listdir(images_dir)

print("List of classes:", classes)
# Out:
# List of classes: ['malignant', 'benign', 'normal', 'Models']

# %% [markdown]
# **We have three classes of Breast Cancer**

# %% [markdown]
# Lets check the number of images in each class

# %%
benign_path = os.path.join(images_dir, "benign")
benign_images = os.listdir(benign_path)
print("length of benign images: ", len(benign_images))

malignant_path = os.path.join(images_dir, "malignant")
malignant_images = os.listdir(malignant_path)
print("length of malignant images: ", len(malignant_images))

normal_path = os.path.join(images_dir, "normal")
normal_images = os.listdir(normal_path)
print("length of normal images: ", len(normal_images))
# Out:
# length of benign images:  891
# length of malignant images:  421
# length of normal images:  266

# %% [markdown]
# **We can clearly see that the classes are unbalance. This is one of the problem with dataset we will deal with these in preprocessing section**

# %% [markdown]
# - **Now let count the no of images and their correspond mask in each class**

# %%
paths = glob(images_dir + "/*/*")
print(f"'normal' class has {len([i for i in paths if 'normal' in i and 'mask' not in i])} images and {len([i for i in paths if 'normal' in i and 'mask' in i])} masks.")
print(f"'benign' class has {len([i for i in paths if 'benign' in i and 'mask' not in i])} images and {len([i for i in paths if 'benign' in i and 'mask' in i])} masks.")
print(f"'malignant' class has {len([i for i in paths if 'malignant' in i and 'mask' not in i])} images and {len([i for i in paths if 'malignant' in i and 'mask' in i])} masks.")
print(f"\nThere are total of {len([i for i in paths if 'mask' not in i])} images and {len([i for i in paths if 'mask' in i])} masks.")
# Out:
# 'normal' class has 133 images and 133 masks.
# 'benign' class has 437 images and 454 masks.
# 'malignant' class has 210 images and 211 masks.
#
# There are total of 780 images and 798 masks.

# %%
import os
from glob import glob

benign_path = os.path.join(images_dir, "benign")
benign_images = os.listdir(benign_path)
print("length of benign images: ", len(benign_images))
# Out:
# length of benign images:  891

# %% [markdown]
# **The reason behind the unequal no of images and mask is that some of the images have more than one mask image, we have to merge these mask images into a single mask image. This is our second problem that we have to tackle**

# %% [markdown]
# ## Size of images

# %%
benign_image_name = benign_images[0]
print(benign_image_name)

benign_image_path = os.path.join(benign_path , benign_image_name)
print(benign_image_path)

print()

malignant_image_name = malignant_images[0]
print(malignant_image_name)

malignant_image_path = os.path.join(malignant_path , malignant_image_name)
print(malignant_image_path)

print()

normal_image_name = normal_images[1]
print(normal_image_name)

normal_image_path = os.path.join(normal_path , normal_image_name)
print(normal_image_path)
# Out:
# benign (108)_mask.png
# /content/drive/MyDrive/dataset/Dataset_BUSI_with_GT/benign/benign (108)_mask.png
#
# malignant (105).png
# /content/drive/MyDrive/dataset/Dataset_BUSI_with_GT/malignant/malignant (105).png
#
# normal (11).png
# /content/drive/MyDrive/dataset/Dataset_BUSI_with_GT/normal/normal (11).png

# %%
benign_img_pil = Image.open(benign_image_path)
print("Benign image: ", benign_img_pil.mode, benign_img_pil.size)

malignant_img_pil = Image.open(malignant_image_path)
print("malignant image: ", malignant_img_pil.mode, malignant_img_pil.size)

normal_img_pil = Image.open(normal_image_path)
print("normal image: ", normal_img_pil.mode, normal_img_pil.size)
# Out:
# Benign image:  1 (769, 582)
# malignant image:  RGB (577, 450)
# normal image:  RGB (752, 576)

# %% [markdown]
# **The images are in RGB mode or channel but the size of the images is different we have to bring all images in the same scale (Normalization)**

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Display each image
axes[0].imshow(benign_img_pil)
axes[0].set_title("Benign")
axes[0].axis('off')

axes[1].imshow(malignant_img_pil)
axes[1].set_title("Malignant")
axes[1].axis('off')

axes[2].imshow(normal_img_pil)
axes[2].set_title("Normal")
axes[2].axis('off')

plt.show()

# %% [markdown]
# # Multimask images

# %%
# Get the 3 image names
benign_image_name = ['benign (100).png', 'benign (100)_mask.png','benign (100)_mask_1.png']
print(benign_image_name)

# Load all 3 images first
images = []
for img_name in benign_image_name:
    img_path = os.path.join(benign_path, img_name)
    img = Image.open(img_path)
    images.append(img)

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].imshow(images[0])
axes[0].set_title("Benign")
axes[0].axis('off')

axes[1].imshow(images[1])
axes[1].set_title("Benign (100)_mask")
axes[1].axis('off')

axes[2].imshow(images[2])
axes[2].set_title("Benign (100)_mask_1")
axes[2].axis('off')

plt.tight_layout()
plt.show()
# Out:
# ['benign (100).png', 'benign (100)_mask.png', 'benign (100)_mask_1.png']

# %% [markdown]
# **So, Here we can see that some the images have separete mask for each breast we have to merge these images into a single image.
# this is the reason that no of images and mask images is not equal**

# %% [markdown]
# # Preprocessing Section

# %% [markdown]
# ## Merging multiple mask into a single mask

# %%
import os
from PIL import Image
import numpy as np

# Define categories
categories = ['benign', 'malignant', 'normal']

def merge_masks(mask_files):
    """Combine multiple binary masks into a single mask using logical OR."""
    merged_mask = None
    for mask_file in mask_files:
        mask = np.array(Image.open(mask_file).convert('1'))  # Binary mask
        if merged_mask is None:
            merged_mask = mask
        else:
            merged_mask = np.logical_or(merged_mask, mask)  # Combine using logical OR
    return Image.fromarray(merged_mask.astype('uint8') * 255)  # Convert to 0–255 for saving

for category in categories:
    category_path = os.path.join(images_dir, category)
    all_files = os.listdir(category_path)

    # Group masks by base image name (remove the "_mask" and any suffixes)
    mask_groups = {}
    for file in all_files:
        if '_mask' in file:  # Identify mask files
            base_name = file.split('_mask')[0]  # Get base name without "_mask"
            if base_name not in mask_groups:
                mask_groups[base_name] = []
            mask_groups[base_name].append(os.path.join(category_path, file))

    # Merge masks and delete duplicates
    for base_name, mask_files in mask_groups.items():
        if len(mask_files) > 1:  # If there are multiple masks for the same base image
            print(f"[{category}] Merging {len(mask_files)} masks for {base_name}...")
            merged_mask = merge_masks(mask_files)

            # Save the merged mask as a single mask image
            merged_mask_path = os.path.join(category_path, f"{base_name}_mask.png")
            merged_mask.save(merged_mask_path)

            # Delete all original mask files except the merged one
            for mask_file in mask_files:
                if mask_file != merged_mask_path:  # Skip the newly created merged mask
                    os.remove(mask_file)
                    print(f"Deleted: {mask_file}")

print("✅ All overlapping masks merged and cleaned up!")
# Out:
# ✅ All overlapping masks merged and cleaned up!

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Paths (replace with your actual paths)
base_name = "benign (100)"  # Example image
mask1_path = "/content/benign (100)_mask.png"
mask2_path = "/content/benign (100)_mask_1.png"

# Load masks and convert to binary (0 or 1)
mask1 = np.array(Image.open(mask1_path).convert('1'))  # Binary mask (True/False)
mask2 = np.array(Image.open(mask2_path).convert('1'))

# Combine masks using logical OR (if either mask has a pixel, keep it)
merged_mask = np.logical_or(mask1, mask2)

# Convert back to PIL Image (0=black, 255=white)
merged_mask_pil = Image.fromarray(merged_mask.astype('uint8') * 255)

# Display the original masks and merged result
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].imshow(mask1, cmap='gray')
axes[0].set_title("Mask 1")
axes[0].axis('off')

axes[1].imshow(mask2, cmap='gray')
axes[1].set_title("Mask 2")
axes[1].axis('off')

axes[2].imshow(merged_mask, cmap='gray')
axes[2].set_title("Merged Mask (OR)")
axes[2].axis('off')

plt.show()

# %% [markdown]
# we merged two single mask in a single image

# %%
# Get the 3 image names
benign_image_name = ['benign (100).png', 'benign (100)_mask.png']
print(benign_image_name)

# Load all 3 images first
images = []
for img_name in benign_image_name:
    img_path = os.path.join(benign_path, img_name)
    img = Image.open(img_path)
    images.append(img)

# Now display them side by side in a single row
fig, axes = plt.subplots(1, 2, figsize=(15, 5))  # 1 row, 3 columns

# Assign each image to a subplot
axes[0].imshow(images[0])
axes[0].set_title("Benign")
axes[0].axis('off')

axes[1].imshow(images[1],cmap = 'gray')
axes[1].set_title("Benign (100)_mask")
axes[1].axis('off')

plt.tight_layout()  # Prevents overlapping titles
plt.show()
# Out:
# ['benign (100).png', 'benign (100)_mask.png']

# %% [markdown]
# - **Now let count again the no of images and their correspond mask in each class**

# %%
paths = glob(images_dir + "/*/*")
print(f"'normal' class has {len([i for i in paths if 'normal' in i and 'mask' not in i])} images and {len([i for i in paths if 'normal' in i and 'mask' in i])} masks.")
print(f"'benign' class has {len([i for i in paths if 'benign' in i and 'mask' not in i])} images and {len([i for i in paths if 'benign' in i and 'mask' in i])} masks.")
print(f"'malignant' class has {len([i for i in paths if 'malignant' in i and 'mask' not in i])} images and {len([i for i in paths if 'malignant' in i and 'mask' in i])} masks.")
print(f"\nThere are total of {len([i for i in paths if 'mask' not in i])} images and {len([i for i in paths if 'mask' in i])} masks.")
# Out:
# 'normal' class has 133 images and 133 masks.
# 'benign' class has 437 images and 437 masks.
# 'malignant' class has 210 images and 210 masks.
#
# There are total of 780 images and 780 masks.

# %% [markdown]
# **we have succesfully merged the images and the tolat no of images is equal to their correspond mask images**

# %% [markdown]
# # Unblance Class Distribution

# %%
# Load dataset
dataset = datasets.ImageFolder(root=images_dir)
print(f"Dataset classes: {dataset.classes}")  # Verify class names

def class_counts(dataset):
    # Count occurrences of each class
    c = Counter(x[1] for x in tqdm(dataset, desc="Counting classes"))

    # Map class indices to names (e.g., {0: 'benign', 1: 'malignant', 2: 'normal'})
    class_to_index = dataset.class_to_idx  # Fixed: No extra .dataset

    # Invert the mapping (e.g., {'benign': 0, 'malignant': 1, 'normal': 2})
    index_to_class = {v: k for k, v in class_to_index.items()}

    # Return counts with class names
    return pd.Series({index_to_class[idx]: count for idx, count in c.items()})

# Get class counts
class_counts = class_counts(dataset)
print(class_counts)
# Out:
# Dataset classes: ['benign', 'malignant', 'normal']
# Counting classes:   0%|          | 0/1560 [00:00<?, ?it/s]
# benign       874
# malignant    420
# normal       266
# dtype: int64

# %%
class_counts.sort_values().plot(kind="bar");

# %% [markdown]
# # Data Spliting Part 80% for training and 20% for validation

# %%
# Config
IMAGE_SIZE = (256, 256)
BATCH_SIZE = 32
DATASET_DIR = images_dir  # Replace with your path

# Class mapping
CLASS_MAP = {"benign": 1, "malignant": 2, "normal": 3}
CLASS_MAP_INV = {v:k for k,v in CLASS_MAP.items()}  # For visualization
IMAGE_EXTENSIONS = [".png", ".jpg", ".jpeg"]

def load_paths():
    image_mask_pairs = []
    for class_name, class_id in CLASS_MAP.items():
        class_dir = os.path.join(DATASET_DIR, class_name)
        files = os.listdir(class_dir)
        image_files = [f for f in files if "_mask" not in f and os.path.splitext(f)[-1].lower() in IMAGE_EXTENSIONS]

        for img_file in image_files:
            base_name = os.path.splitext(img_file)[0]
            image_path = os.path.join(class_dir, img_file)
            mask_path = os.path.join(class_dir, f"{base_name}_mask{os.path.splitext(img_file)[1]}")

            if os.path.exists(mask_path):
                image_mask_pairs.append((image_path, mask_path, class_id))
    return image_mask_pairs

def process_path(image_path, mask_path, class_id):
    image = load_img(image_path, target_size=IMAGE_SIZE)
    image = img_to_array(image) / 255.0
    mask = load_img(mask_path, color_mode="grayscale", target_size=IMAGE_SIZE)
    mask = img_to_array(mask)
    mask = np.where(mask > 0, class_id, 0)
    return image, mask

def load_data_with_labels():
    data = load_paths()
    images, masks, labels = [], [], []
    for img_path, mask_path, class_id in data:
        image, mask = process_path(img_path, mask_path, class_id)
        images.append(image)
        masks.append(mask)
        labels.append(class_id)
    return np.array(images), np.array(masks), np.array(labels)
# Load and split data
images, masks, labels = load_data_with_labels()
X_train, X_val, y_train, y_val, labels_train, labels_val = train_test_split(
    images, masks, labels, test_size=0.2, stratify=labels, random_state=42)

# %%
def plot_image_mask_counts(X_train, y_train, labels_train):

    assert len(X_train) == len(y_train) == len(labels_train), "Mismatched array lengths!"

    # Get class counts
    class_counts = Counter(labels_train)
    classes = [CLASS_MAP_INV[c] for c in class_counts.keys()]
    counts = list(class_counts.values())

    # Create plot
    plt.figure(figsize=(10, 10))

    # Plot image counts (will be same as mask counts)
    bars = plt.bar(classes, counts, color=['skyblue', 'salmon', 'lightgreen'],
                  edgecolor='black', width=0.4)

    plt.title("Image and Mask Counts by Class", pad=20, fontsize=14)
    plt.xlabel("Class", labelpad=10, fontsize=12)
    plt.ylabel("Count (Images = Masks)", labelpad=10, fontsize=12)
    plt.xticks(fontsize=11)

    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height,
                f'Images: {height}\nMasks: {height}',
                ha='center', va='bottom', fontsize=11)

    # Add verification text
    total_pairs = len(X_train)
    plt.text(0.95, 0.95,
             f"Total Image-Mask Pairs: {total_pairs}\n(Verified 1:1 correspondence)",
             transform=plt.gca().transAxes,
             ha='right', va='top',
             bbox=dict(facecolor='white', alpha=0.8, edgecolor='gray'))

    plt.grid(axis='y', linestyle='--', alpha=0.4)
    plt.tight_layout()
    plt.show()

# Usage
print("Training Data Verification:")
plot_image_mask_counts(X_train, y_train, labels_train)
# Out:
# Training Data Verification:

# %% [markdown]
# # Augmentation on training dataset to blance the imbalance classes

# %%
def apply_augmentation(image, mask):
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)


    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    image = tf.clip_by_value(image, 0.0, 1.0)

    return image, mask

def balance_classes(X_train, y_train, labels_train):

    labels_train = np.array(labels_train)

    # Get indices for each class
    benign_idx = np.where(labels_train == 1)[0]  # benign
    malignant_idx = np.where(labels_train == 2)[0]  # malignant
    normal_idx = np.where(labels_train == 3)[0]  # normal

    print("Original counts:")
    print(f"Benign (1): {len(benign_idx)}")
    print(f"Malignant (2): {len(malignant_idx)}")
    print(f"Normal (3): {len(normal_idx)}")


    X_benign = X_train[benign_idx]
    y_benign = y_train[benign_idx]


    X_malignant = X_train[malignant_idx]
    y_malignant = y_train[malignant_idx]

    malignant_needed = 350 - 168  # = 182 augmentations needed
    augmented_malignant = []
    augmented_malignant_masks = []

    for _ in range(malignant_needed):
        idx = np.random.randint(0, 168)  # randomly select from original 168
        img = tf.convert_to_tensor(X_malignant[idx])
        mask = tf.convert_to_tensor(y_malignant[idx])
        aug_img, aug_mask = apply_augmentation(img, mask)
        augmented_malignant.append(aug_img.numpy())
        augmented_malignant_masks.append(aug_mask.numpy())

    # Combine original + augmented malignant
    X_malignant = np.concatenate([X_malignant, augmented_malignant])
    y_malignant = np.concatenate([y_malignant, augmented_malignant_masks])

    # 3. Normal - augment from 106 → 250 (need +144)
    X_normal = X_train[normal_idx]
    y_normal = y_train[normal_idx]

    normal_needed = 250 - 106  # = 144 augmentations needed
    augmented_normal = []
    augmented_normal_masks = []

    for _ in range(normal_needed):
        idx = np.random.randint(0, 106)  # randomly select from original 106
        img = tf.convert_to_tensor(X_normal[idx])
        mask = tf.convert_to_tensor(y_normal[idx])
        aug_img, aug_mask = apply_augmentation(img, mask)
        augmented_normal.append(aug_img.numpy())
        augmented_normal_masks.append(aug_mask.numpy())

    # Combine original + augmented normal
    X_normal = np.concatenate([X_normal, augmented_normal])
    y_normal = np.concatenate([y_normal, augmented_normal_masks])

    # Combine all classes
    X_balanced = np.concatenate([X_benign, X_malignant, X_normal])
    y_balanced = np.concatenate([y_benign, y_malignant, y_normal])
    labels_balanced = np.concatenate([
        np.full(350, 1),  # benign
        np.full(350, 2),  # malignant
        np.full(250, 3)   # normal
    ])

    # Verify
    print("\nBalanced counts:")
    print(f"Benign (1): {np.sum(labels_balanced == 1)}")
    print(f"Malignant (2): {np.sum(labels_balanced == 2)}")
    print(f"Normal (3): {np.sum(labels_balanced == 3)}")

    return X_balanced, y_balanced, labels_balanced

# Apply balancing
X_train_balanced, y_train_balanced, labels_train_balanced = balance_classes(X_train, y_train, labels_train)
# Out:
# Original counts:
# Benign (1): 350
# Malignant (2): 168
# Normal (3): 106
#
# Balanced counts:
# Benign (1): 350
# Malignant (2): 350
# Normal (3): 250

# %%
def plot_image_mask_counts(X_train, y_train, labels_train):

    assert len(X_train) == len(y_train) == len(labels_train), "Mismatched array lengths!"
    class_counts = Counter(labels_train)
    classes = [CLASS_MAP_INV[c] for c in class_counts.keys()]
    counts = list(class_counts.values())


    plt.figure(figsize=(10, 10))
    bars = plt.bar(classes, counts, color=['skyblue', 'salmon', 'lightgreen'],
                  edgecolor='black', width=0.4)

    plt.title("Image and Mask Counts by Class", pad=20, fontsize=14)
    plt.xlabel("Class", labelpad=10, fontsize=12)
    plt.ylabel("Count (Images = Masks)", labelpad=10, fontsize=12)
    plt.xticks(fontsize=11)

    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height,
                f'Images: {height}\nMasks: {height}',
                ha='center', va='bottom', fontsize=11)

    total_pairs = len(X_train)
    plt.text(0.95, 0.95,
             f"Total Image-Mask Pairs: {total_pairs}\n(Verified 1:1 correspondence)",
             transform=plt.gca().transAxes,
             ha='right', va='top',
             bbox=dict(facecolor='white', alpha=0.8, edgecolor='gray'))

    plt.grid(axis='y', linestyle='--', alpha=0.4)
    plt.tight_layout()
    plt.show()

print("Training Data Verification:")
plot_image_mask_counts(X_train_balanced, y_train_balanced, labels_train_balanced)
# Out:
# Training Data Verification:

# %%
def create_dataset(x, y, shuffle=True):
    ds = tf.data.Dataset.from_tensor_slices((x, y))
    ds = ds.map(lambda a, b: (tf.cast(a, tf.float32), tf.cast(b, tf.int32)))
    if shuffle:
        ds = ds.shuffle(1000)
    return ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# train_ds = create_dataset(X_train_balanced, y_train_balanced)
val_ds = create_dataset(X_val, y_val, shuffle=False)

print("\nFinal Dataset Sizes:")
# print(f"Balanced training samples: {len(X_train_balanced)}")
print(f"Validation samples: {len(X_val)}")
# Out:
# Final Dataset Sizes:
# Validation samples: 156

# %%
X_train_balanced.shape, y_train_balanced.shape, X_val.shape, y_val.shape
# Out:
# ((950, 256, 256, 3),
#  (950, 256, 256, 1),
#  (156, 256, 256, 3),
#  (156, 256, 256, 1))

# %% [markdown]
# # Some of the images with their repective mask image in train dataset

# %%
for images, masks in train_ds.take(2):
    batch_size = images.shape[0]  # get how many images are in this batch

# Display images and masks
plt.figure(figsize=(15, 8))
for i in range(min(batch_size, 5)):  # show up to 5 images
    # Display image
    plt.subplot(2, 5, i + 1)
    plt.imshow(images[i])
    plt.title(f"Image {i+1}")
    plt.axis('off')

    # Display corresponding mask
    plt.subplot(2, 5, i + 6)
    plt.imshow(masks[i].numpy().squeeze(), cmap='gray')

    plt.title(f"Mask {i+1}")
    plt.axis('off')

plt.suptitle("Training Images and Their Masks", y=1.05)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Unet Model

# %% [markdown]
# Model Description:
#
# In this project, we address the task of breast cancer image segmentation, where each image is paired with a corresponding mask image annotated into three classes: benign, malignant, and normal. As requested by the client, we implemented a U-Net-based convolutional neural network (CNN) architecture, which is widely used for biomedical image segmentation tasks due to its effective encoder-decoder structure.
#
# The model consists of:
#
# Encoder blocks that progressively extract spatial features through convolution and max-pooling layers.
#
# A bottleneck layer that captures deep feature representations.
#
# Decoder blocks that upsample the feature maps and concatenate them with corresponding encoder features (skip connections) to preserve spatial context.
#
# A final softmax-activated convolution layer to produce pixel-wise class probabilities for three classes.
#
# The model is compiled using sparse categorical crossentropy (since the mask labels are integer-encoded: 0, 1, 2) and optimized with Adam optimizer. This architecture is specifically designed to effectively learn the spatial boundaries of each class within breast cancer images, ensuring accurate segmentation performance

# %%
import tensorflow as tf
from keras.models import Model
from keras.optimizers import Adam
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPooling2D, UpSampling2D, concatenate, add,Input,Conv2DTranspose, concatenate
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.layers import BatchNormalization,Activation
from tensorflow.keras.metrics import *
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Dropout

# %%
# Number of classes
NUM_CLASSES = 3

def dice_coefficient(y_true, y_pred, smooth=1):
    # Squeeze if needed
    y_true = tf.squeeze(y_true, axis=-1)  # Always squeeze last dimension

    # One-hot encode ground truth
    y_true = tf.one_hot(tf.cast(y_true, tf.int32), NUM_CLASSES)  # (batch, 256, 256, 3)

    # Clip predictions
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)

    # Compute intersection and union
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3])

    dice = (2. * intersection + smooth) / (union + smooth)
    return tf.reduce_mean(dice)  # mean over batch


# 🔥 U-Net building blocks
def conv_block(input, num_filters, dropout_rate=0.1):
    conv = Conv2D(num_filters, (3, 3), activation="relu", padding="same", kernel_initializer='he_normal')(input)
    conv = Conv2D(num_filters, (3, 3), activation="relu", padding="same", kernel_initializer='he_normal')(conv)
    if dropout_rate > 0.0:
        conv = Dropout(dropout_rate)(conv)
    return conv

def encoder_block(input, num_filters, dropout_rate=0.0):
    conv = conv_block(input, num_filters, dropout_rate)
    pool = MaxPooling2D((2, 2))(conv)
    return conv, pool

def decoder_block(input, skip_features, num_filters, dropout_rate=0.0):
    uconv = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    con = concatenate([uconv, skip_features])
    conv = conv_block(con, num_filters, dropout_rate)
    return conv

def build_model(input_shape, num_classes=3, dropout_rate=0.3):
    input_layer = Input(input_shape)

    s1, p1 = encoder_block(input_layer, 64, dropout_rate)
    s2, p2 = encoder_block(p1, 128, dropout_rate)
    s3, p3 = encoder_block(p2, 256, dropout_rate)
    s4, p4 = encoder_block(p3, 512, dropout_rate)

    b1 = conv_block(p4, 1024, dropout_rate)

    d1 = decoder_block(b1, s4, 512, dropout_rate)
    d2 = decoder_block(d1, s3, 256, dropout_rate)
    d3 = decoder_block(d2, s2, 128, dropout_rate)
    d4 = decoder_block(d3, s1, 64, dropout_rate)

    output_layer = Conv2D(num_classes, (1, 1), padding="same", activation="softmax")(d4)

    model = Model(input_layer, output_layer, name="U-Net")
    return model

# 🏗 Build and compile the model
unet = build_model(input_shape=(256, 256, 3), num_classes=3, dropout_rate=0.2)

# Use sparse categorical crossentropy for integer masks
unet.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="Adam",
    metrics=["accuracy", dice_coefficient]
)

# %% [markdown]
# Train on 100 ephocs and with batch size of 32

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)

history = unet.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 117s 2s/step - loss: 2.2596 - accuracy: 0.8893 - dice_coefficient: 0.6895 - val_loss: 0.4816 - val_accuracy: 0.9059 - val_dice_coefficient: 0.7965
# Epoch 2/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.3740 - accuracy: 0.9210 - dice_coefficient: 0.8249 - val_loss: 0.4594 - val_accuracy: 0.9059 - val_dice_coefficient: 0.8738
# Epoch 3/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.3437 - accuracy: 0.9212 - dice_coefficient: 0.8401 - val_loss: 0.3559 - val_accuracy: 0.9059 - val_dice_coefficient: 0.8520
# Epoch 4/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.2995 - accuracy: 0.9214 - dice_coefficient: 0.8574 - val_loss: 0.3229 - val_accuracy: 0.9059 - val_dice_coefficient: 0.8549
# Epoch 5/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.2808 - accuracy: 0.9214 - dice_coefficient: 0.8609 - val_loss: 0.3137 - val_accuracy: 0.9059 - val_dice_coefficient: 0.8619
# Epoch 6/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.2697 - accuracy: 0.9214 - dice_coefficient: 0.8662 - val_loss: 0.3138 - val_accuracy: 0.9059 - val_dice_coefficient: 0.8358
# Epoch 7/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.2607 - accuracy: 0.9215 - dice_coefficient: 0.8682 - val_loss: 0.3199 - val_accuracy: 0.9059 - val_dice_coefficient: 0.8835
# Epoch 8/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.2622 - accuracy: 0.9224 - dice_coefficient: 0.8717 - val_loss: 0.3113 - val_accuracy: 0.9059 - val_dice_coefficient: 0.8442
# Epoch 9/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.2551 - accuracy: 0.9228 - dice_coefficient: 0.8712 - val_loss: 0.3020 - val_accuracy: 0.9060 - val_dice_coefficient: 0.8800
# Epoch 10/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.2438 - accuracy: 0.9240 - dice_coefficient: 0.8776 - val_loss: 0.2830 - val_accuracy: 0.9118 - val_dice_coefficient: 0.8753
# Epoch 11/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.2359 - accuracy: 0.9255 - dice_coefficient: 0.8808 - val_loss: 0.2673 - val_accuracy: 0.9140 - val_dice_coefficient: 0.8752
# Epoch 12/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.2265 - accuracy: 0.9287 - dice_coefficient: 0.8854 - val_loss: 0.2850 - val_accuracy: 0.9148 - val_dice_coefficient: 0.8932
# Epoch 13/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.2302 - accuracy: 0.9272 - dice_coefficient: 0.8836 - val_loss: 0.2818 - val_accuracy: 0.9135 - val_dice_coefficient: 0.8793
# Epoch 14/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.2142 - accuracy: 0.9306 - dice_coefficient: 0.8929 - val_loss: 0.2875 - val_accuracy: 0.9120 - val_dice_coefficient: 0.8960
# Epoch 15/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.2089 - accuracy: 0.9322 - dice_coefficient: 0.8943 - val_loss: 0.2717 - val_accuracy: 0.9148 - val_dice_coefficient: 0.8803
# Epoch 16/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.2043 - accuracy: 0.9341 - dice_coefficient: 0.8975 - val_loss: 0.2488 - val_accuracy: 0.9209 - val_dice_coefficient: 0.8983
# Epoch 17/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.1945 - accuracy: 0.9373 - dice_coefficient: 0.9021 - val_loss: 0.2833 - val_accuracy: 0.9126 - val_dice_coefficient: 0.8976
# Epoch 18/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.1969 - accuracy: 0.9359 - dice_coefficient: 0.9019 - val_loss: 0.2389 - val_accuracy: 0.9258 - val_dice_coefficient: 0.8799
# Epoch 19/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.1882 - accuracy: 0.9391 - dice_coefficient: 0.9034 - val_loss: 0.2839 - val_accuracy: 0.9161 - val_dice_coefficient: 0.9039
# Epoch 20/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.1865 - accuracy: 0.9384 - dice_coefficient: 0.9070 - val_loss: 0.2513 - val_accuracy: 0.9212 - val_dice_coefficient: 0.9050
# Epoch 21/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.1758 - accuracy: 0.9433 - dice_coefficient: 0.9108 - val_loss: 0.2577 - val_accuracy: 0.9243 - val_dice_coefficient: 0.9097
# Epoch 22/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.1736 - accuracy: 0.9434 - dice_coefficient: 0.9132 - val_loss: 0.2346 - val_accuracy: 0.9291 - val_dice_coefficient: 0.8894
# Epoch 23/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.1629 - accuracy: 0.9474 - dice_coefficient: 0.9167 - val_loss: 0.2422 - val_accuracy: 0.9200 - val_dice_coefficient: 0.9031
# Epoch 24/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.1704 - accuracy: 0.9446 - dice_coefficient: 0.9145 - val_loss: 0.2409 - val_accuracy: 0.9245 - val_dice_coefficient: 0.9077
# Epoch 25/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.1538 - accuracy: 0.9502 - dice_coefficient: 0.9223 - val_loss: 0.2212 - val_accuracy: 0.9315 - val_dice_coefficient: 0.8990
# Epoch 26/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.1476 - accuracy: 0.9515 - dice_coefficient: 0.9246 - val_loss: 0.2103 - val_accuracy: 0.9332 - val_dice_coefficient: 0.9089
# Epoch 27/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.1447 - accuracy: 0.9518 - dice_coefficient: 0.9257 - val_loss: 0.2140 - val_accuracy: 0.9315 - val_dice_coefficient: 0.9140
# Epoch 28/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.1305 - accuracy: 0.9567 - dice_coefficient: 0.9333 - val_loss: 0.2307 - val_accuracy: 0.9325 - val_dice_coefficient: 0.9205
# Epoch 29/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.1304 - accuracy: 0.9579 - dice_coefficient: 0.9345 - val_loss: 0.2196 - val_accuracy: 0.9333 - val_dice_coefficient: 0.9161
# Epoch 30/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.1293 - accuracy: 0.9581 - dice_coefficient: 0.9345 - val_loss: 0.2308 - val_accuracy: 0.9354 - val_dice_coefficient: 0.9241
# Epoch 31/50
# 30/30 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9601 - dice_coefficient: 0.9388Restoring model weights from the end of the best epoch: 26.
# 30/30 [==============================] - 34s 1s/step - loss: 0.1205 - accuracy: 0.9601 - dice_coefficient: 0.9388 - val_loss: 0.2217 - val_accuracy: 0.9361 - val_dice_coefficient: 0.9183
# Epoch 31: early stopping

# %% [markdown]
# # Accuracy of Unet Model

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,3))
ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax[0].legend()
ax[1].plot(history.epoch, history.history["accuracy"], label="Train accuracy")
ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation accuracy")
ax[1].legend()
fig.suptitle('Loss and Accuracy', fontsize=16)
plt.show()

# %% [markdown]
# # Prediction through Unet Model

# %%
for images, masks in val_ds.take(2):
    break

fig, ax = plt.subplots(5, 3, figsize=(10, 18))

j = np.random.randint(0, images.shape[0], 5)
for i in range(5):
    # Original Image
    ax[i, 0].imshow(np.squeeze(images[j[i]]), cmap='gray')
    ax[i, 0].set_title('Image')

    # Ground Truth Mask
    ax[i, 1].imshow(np.squeeze(masks[j[i]]), cmap='gray')
    ax[i, 1].set_title('Mask')

    # Prediction (argmax to get class indices)
    prediction = unet.predict(np.expand_dims(images[j[i]], 0), verbose=0)
    predicted_mask = np.argmax(prediction[0], axis=-1)   # <-- this converts softmax to class labels
    ax[i, 2].imshow(predicted_mask, cmap='gray')
    ax[i, 2].set_title('Prediction')

for a in ax.flatten():
    a.axis('off')

fig.suptitle('Results', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# **The model prediction is quite good but we can see that the model also predicting segmentation for normal classes, we need to handle this problem.**

# %% [markdown]
# # Evaltion Metrics of Unet Model

# %%
# Accumulators
all_preds = []
all_masks = []

# Loop through the full validation dataset
for images, masks in val_ds:
    preds = unet.predict(images, verbose=0)
    preds_labels = np.argmax(preds, axis=-1)  # (batch_size, H, W)
    masks_labels = np.squeeze(masks, axis=-1)  # (batch_size, H, W)

    all_preds.append(preds_labels)
    all_masks.append(masks_labels)

# Stack everything to single arrays
all_preds = np.concatenate(all_preds, axis=0)
all_masks = np.concatenate(all_masks, axis=0)

# Compute Mean IoU
IOU_keras = MeanIoU(num_classes=3)
IOU_keras.update_state(all_masks, all_preds)
print("Mean IoU =", IOU_keras.result().numpy())

# Flatten for sklearn metrics
y_pred_flat = all_preds.flatten().astype(np.uint8)
y_true_flat = all_masks.flatten().astype(np.uint8)

# Compute precision, recall, F1, Dice (macro averaged)
p = precision_score(y_true_flat, y_pred_flat, average='macro')
r = recall_score(y_true_flat, y_pred_flat, average='macro')
f1 = f1_score(y_true_flat, y_pred_flat, average='macro')
dice = f1  # F1 = Dice in multiclass

print(f'Dice Score (macro) = {dice:.3f}')
print(f'Precision Score = {p:.3f}')
print(f'Recall Score = {r:.3f}')
print(f'F1 Score = {f1:.3f}')
# Out:
# Mean IoU = 0.49043247
# Dice Score (macro) = 0.596
# Precision Score = 0.812
# Recall Score = 0.566
# F1 Score = 0.596

# %%
unet.save(r"C:\Users\drimr\Desktop\FYP Bachelors\FYP Ultrasound\Code and Data\unet.h5")

# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# %% [markdown]
# # Unet Model Hyper Parameter Tuning

# %% [markdown]
# 1. Add Early Stopping
# Stop training when validation loss stops improving.good to prvent overfitting
#
# 2. Add Model Checkpointing
# Save the best model based on validation IoU or loss.
#
# 3. Use Learning Rate Scheduler (ReduceLROnPlateau)
# Reduce learning rate when a metric has stopped improving.
#
# 4. Batch Normalization
# Between convolution and activation — improves convergence and stability. helps to bost traing speed and stability
#
# 5. batch size should be 16. 16 is a good balance for 256×256 images and stability

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Input, BatchNormalization, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint



def dice_coefficient(y_true, y_pred, smooth=1):
    y_true = tf.one_hot(tf.squeeze(tf.cast(y_true, tf.int32), axis=-1), 3)
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)

    dice = (2. * intersection + smooth) / (union + smooth)
    return dice

def conv_block(input, num_filters):
    conv = Conv2D(num_filters, (3, 3), padding="same", kernel_initializer='he_normal')(input)
    conv = BatchNormalization()(conv)
    conv = Activation("relu")(conv)
    conv = Conv2D(num_filters, (3, 3), padding="same", kernel_initializer='he_normal')(conv)
    conv = BatchNormalization()(conv)
    conv = Activation("relu")(conv)
    return conv


def encoder_block(input, num_filters):
    conv = conv_block(input, num_filters)
    pool = MaxPooling2D((2, 2))(conv)
    return conv, pool

def decoder_block(input, skip_features, num_filters):
    uconv = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    con = concatenate([uconv, skip_features])
    conv = conv_block(con, num_filters)
    return conv

def build_model(input_shape, num_classes=3):
    input_layer = Input(input_shape)

    s1, p1 = encoder_block(input_layer, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    # Final softmax for 3-class output per pixel
    output_layer = Conv2D(num_classes, (1, 1), padding="same", activation="softmax")(d4)

    model = Model(input_layer, output_layer, name="U-Net")
    return model

tuned_unet = build_model(input_shape=(256, 256, 3), num_classes=3)

# Use sparse_categorical_crossentropy because masks have integer class labels 0, 1, 2
tuned_unet.compile(loss="sparse_categorical_crossentropy", optimizer="Adam", metrics=["accuracy",dice_coefficient])
#tuned_unet.summary()

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# Callbacks
early_stop = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=10,
    mode='max',  # <--- important
    restore_best_weights=True,
    verbose=1
)
# checkpoint = ModelCheckpoint('best_unet_model.h5', monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)

# Train with callbacks
history = tuned_unet.fit(
    train_ds,
    epochs=50,
    validation_data = val_ds,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.8007 - dice_coefficient: 0.6397 - loss: 0.6280 - val_accuracy: 0.0386 - val_dice_coefficient: 0.0383 - val_loss: 234138.0781 - learning_rate: 0.0010
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.9241 - dice_coefficient: 0.8496 - loss: 0.3074 - val_accuracy: 0.1575 - val_dice_coefficient: 0.1567 - val_loss: 173.7550 - learning_rate: 0.0010
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9227 - dice_coefficient: 0.8545 - loss: 0.3015 - val_accuracy: 0.0814 - val_dice_coefficient: 0.0754 - val_loss: 34.8998 - learning_rate: 0.0010
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.9218 - dice_coefficient: 0.8538 - loss: 0.3036 - val_accuracy: 0.2940 - val_dice_coefficient: 0.2734 - val_loss: 3.2337 - learning_rate: 0.0010
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9226 - dice_coefficient: 0.8593 - loss: 0.2755 - val_accuracy: 0.0556 - val_dice_coefficient: 0.0554 - val_loss: 39.9345 - learning_rate: 0.0010
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9212 - dice_coefficient: 0.8719 - loss: 0.2574 - val_accuracy: 0.7499 - val_dice_coefficient: 0.7296 - val_loss: 2.3785 - learning_rate: 0.0010
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9296 - dice_coefficient: 0.8817 - loss: 0.2244 - val_accuracy: 0.1553 - val_dice_coefficient: 0.1572 - val_loss: 6.0311 - learning_rate: 0.0010
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9336 - dice_coefficient: 0.8945 - loss: 0.2053 - val_accuracy: 0.1495 - val_dice_coefficient: 0.1650 - val_loss: 4.3027 - learning_rate: 0.0010
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9296 - dice_coefficient: 0.8906 - loss: 0.2124 - val_accuracy: 0.8511 - val_dice_coefficient: 0.8036 - val_loss: 0.4140 - learning_rate: 0.0010
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9419 - dice_coefficient: 0.9083 - loss: 0.1850 - val_accuracy: 0.2987 - val_dice_coefficient: 0.2972 - val_loss: 3.2395 - learning_rate: 0.0010
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9390 - dice_coefficient: 0.9030 - loss: 0.1908 - val_accuracy: 0.6843 - val_dice_coefficient: 0.6569 - val_loss: 0.7397 - learning_rate: 0.0010
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9428 - dice_coefficient: 0.9081 - loss: 0.1763 - val_accuracy: 0.7956 - val_dice_coefficient: 0.7553 - val_loss: 0.4703 - learning_rate: 0.0010
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9403 - dice_coefficient: 0.9069 - loss: 0.1843 - val_accuracy: 0.7422 - val_dice_coefficient: 0.7110 - val_loss: 0.6347 - learning_rate: 0.0010
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.9430 - dice_coefficient: 0.9132 - loss: 0.1707 - val_accuracy: 0.8992 - val_dice_coefficient: 0.8760 - val_loss: 0.2790 - learning_rate: 0.0010
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9436 - dice_coefficient: 0.9112 - loss: 0.1750 - val_accuracy: 0.9216 - val_dice_coefficient: 0.9016 - val_loss: 0.2904 - learning_rate: 0.0010
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9394 - dice_coefficient: 0.9092 - loss: 0.1827 - val_accuracy: 0.8539 - val_dice_coefficient: 0.8329 - val_loss: 0.5031 - learning_rate: 0.0010
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9483 - dice_coefficient: 0.9195 - loss: 0.1595 - val_accuracy: 0.7616 - val_dice_coefficient: 0.7434 - val_loss: 0.6075 - learning_rate: 0.0010
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9498 - dice_coefficient: 0.9208 - loss: 0.1531 - val_accuracy: 0.9295 - val_dice_coefficient: 0.9074 - val_loss: 0.2050 - learning_rate: 0.0010
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9474 - dice_coefficient: 0.9189 - loss: 0.1572 - val_accuracy: 0.9404 - val_dice_coefficient: 0.9132 - val_loss: 0.1867 - learning_rate: 0.0010
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9493 - dice_coefficient: 0.9220 - loss: 0.1491 - val_accuracy: 0.9339 - val_dice_coefficient: 0.9256 - val_loss: 0.2786 - learning_rate: 0.0010
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9525 - dice_coefficient: 0.9247 - loss: 0.1403 - val_accuracy: 0.9367 - val_dice_coefficient: 0.9145 - val_loss: 0.1960 - learning_rate: 0.0010
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9511 - dice_coefficient: 0.9239 - loss: 0.1430 - val_accuracy: 0.9414 - val_dice_coefficient: 0.9271 - val_loss: 0.2171 - learning_rate: 0.0010
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9495 - dice_coefficient: 0.9259 - loss: 0.1454 - val_accuracy: 0.9413 - val_dice_coefficient: 0.9302 - val_loss: 0.2155 - learning_rate: 0.0010
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9491 - dice_coefficient: 0.9253 - loss: 0.1478
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9492 - dice_coefficient: 0.9254 - loss: 0.1476 - val_accuracy: 0.9320 - val_dice_coefficient: 0.9250 - val_loss: 0.2831 - learning_rate: 0.0010
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9554 - dice_coefficient: 0.9293 - loss: 0.1271 - val_accuracy: 0.9448 - val_dice_coefficient: 0.9343 - val_loss: 0.1865 - learning_rate: 5.0000e-04
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9609 - dice_coefficient: 0.9402 - loss: 0.1155 - val_accuracy: 0.9402 - val_dice_coefficient: 0.9184 - val_loss: 0.1947 - learning_rate: 5.0000e-04
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9613 - dice_coefficient: 0.9409 - loss: 0.1114 - val_accuracy: 0.9423 - val_dice_coefficient: 0.9346 - val_loss: 0.2123 - learning_rate: 5.0000e-04
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9629 - dice_coefficient: 0.9424 - loss: 0.1078 - val_accuracy: 0.9317 - val_dice_coefficient: 0.9272 - val_loss: 0.2749 - learning_rate: 5.0000e-04
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9642 - dice_coefficient: 0.9443 - loss: 0.1010 - val_accuracy: 0.9422 - val_dice_coefficient: 0.9289 - val_loss: 0.1928 - learning_rate: 5.0000e-04
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9676 - dice_coefficient: 0.9497 - loss: 0.0939
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9676 - dice_coefficient: 0.9497 - loss: 0.0940 - val_accuracy: 0.9416 - val_dice_coefficient: 0.9327 - val_loss: 0.2054 - learning_rate: 5.0000e-04
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9675 - dice_coefficient: 0.9472 - loss: 0.0933 - val_accuracy: 0.9439 - val_dice_coefficient: 0.9367 - val_loss: 0.2087 - learning_rate: 2.5000e-04
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9701 - dice_coefficient: 0.9536 - loss: 0.0852 - val_accuracy: 0.9422 - val_dice_coefficient: 0.9349 - val_loss: 0.2318 - learning_rate: 2.5000e-04
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9708 - dice_coefficient: 0.9554 - loss: 0.0803 - val_accuracy: 0.9410 - val_dice_coefficient: 0.9333 - val_loss: 0.2341 - learning_rate: 2.5000e-04
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9676 - dice_coefficient: 0.9523 - loss: 0.0891 - val_accuracy: 0.9411 - val_dice_coefficient: 0.9320 - val_loss: 0.2216 - learning_rate: 2.5000e-04
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9746 - dice_coefficient: 0.9600 - loss: 0.0705
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9746 - dice_coefficient: 0.9600 - loss: 0.0706 - val_accuracy: 0.9458 - val_dice_coefficient: 0.9353 - val_loss: 0.1968 - learning_rate: 2.5000e-04
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9767 - dice_coefficient: 0.9615 - loss: 0.0661 - val_accuracy: 0.9404 - val_dice_coefficient: 0.9341 - val_loss: 0.2304 - learning_rate: 1.2500e-04
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9769 - dice_coefficient: 0.9634 - loss: 0.0640 - val_accuracy: 0.9479 - val_dice_coefficient: 0.9392 - val_loss: 0.2012 - learning_rate: 1.2500e-04
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9785 - dice_coefficient: 0.9650 - loss: 0.0615 - val_accuracy: 0.9465 - val_dice_coefficient: 0.9378 - val_loss: 0.2033 - learning_rate: 1.2500e-04
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9793 - dice_coefficient: 0.9669 - loss: 0.0574 - val_accuracy: 0.9451 - val_dice_coefficient: 0.9375 - val_loss: 0.2168 - learning_rate: 1.2500e-04
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9800 - dice_coefficient: 0.9673 - loss: 0.0571
# Epoch 40: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9800 - dice_coefficient: 0.9673 - loss: 0.0570 - val_accuracy: 0.9468 - val_dice_coefficient: 0.9397 - val_loss: 0.2129 - learning_rate: 1.2500e-04
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9829 - dice_coefficient: 0.9715 - loss: 0.0488 - val_accuracy: 0.9458 - val_dice_coefficient: 0.9387 - val_loss: 0.2168 - learning_rate: 6.2500e-05
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9836 - dice_coefficient: 0.9721 - loss: 0.0463 - val_accuracy: 0.9493 - val_dice_coefficient: 0.9411 - val_loss: 0.1991 - learning_rate: 6.2500e-05
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9827 - dice_coefficient: 0.9715 - loss: 0.0490 - val_accuracy: 0.9494 - val_dice_coefficient: 0.9419 - val_loss: 0.2020 - learning_rate: 6.2500e-05
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9838 - dice_coefficient: 0.9727 - loss: 0.0456 - val_accuracy: 0.9503 - val_dice_coefficient: 0.9428 - val_loss: 0.1998 - learning_rate: 6.2500e-05
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9835 - dice_coefficient: 0.9726 - loss: 0.0461
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9835 - dice_coefficient: 0.9725 - loss: 0.0461 - val_accuracy: 0.9497 - val_dice_coefficient: 0.9416 - val_loss: 0.1949 - learning_rate: 6.2500e-05
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9843 - dice_coefficient: 0.9740 - loss: 0.0439 - val_accuracy: 0.9493 - val_dice_coefficient: 0.9403 - val_loss: 0.1932 - learning_rate: 3.1250e-05
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9853 - dice_coefficient: 0.9752 - loss: 0.0412 - val_accuracy: 0.9502 - val_dice_coefficient: 0.9424 - val_loss: 0.1956 - learning_rate: 3.1250e-05
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.9852 - dice_coefficient: 0.9747 - loss: 0.0424 - val_accuracy: 0.9507 - val_dice_coefficient: 0.9426 - val_loss: 0.1921 - learning_rate: 3.1250e-05
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9849 - dice_coefficient: 0.9745 - loss: 0.0423 - val_accuracy: 0.9509 - val_dice_coefficient: 0.9430 - val_loss: 0.1925 - learning_rate: 3.1250e-05
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9860 - dice_coefficient: 0.9762 - loss: 0.0392
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9860 - dice_coefficient: 0.9762 - loss: 0.0392 - val_accuracy: 0.9501 - val_dice_coefficient: 0.9417 - val_loss: 0.1933 - learning_rate: 3.1250e-05
# Restoring model weights from the end of the best epoch: 49.

# %%
tuned_unet.save(r"content/drive/MyDrive/newmodels/tuned_unet.h5")

# %% [markdown]
# # Accuracy of Tuned Unet Model

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,3))
ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax[0].legend()
ax[1].plot(history.epoch, history.history["accuracy"], label="Train accuracy")
ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation accuracy")
ax[1].legend()
fig.suptitle('Loss and Accuracy', fontsize=16)
plt.show()

# %% [markdown]
# **The training accuracy is 0.9607 and val accuracy is 0.9516 also training loss is 0.1049 and val loss is 0.1326**
#
# - After tuning we can see that the model is now much generalize model. their less variance between the losses.

# %%
for images, masks in val_ds.take(2):
    break

fig, ax = plt.subplots(5, 3, figsize=(10, 18))

j = np.random.randint(0, images.shape[0], 5)
for i in range(5):
    # Original Image
    ax[i, 0].imshow(np.squeeze(images[j[i]]), cmap='gray')
    ax[i, 0].set_title('Image')

    # Ground Truth Mask
    ax[i, 1].imshow(np.squeeze(masks[j[i]]), cmap='gray')
    ax[i, 1].set_title('Mask')

    # Prediction (argmax to get class indices)
    prediction = tuned_unet.predict(np.expand_dims(images[j[i]], 0), verbose=0)
    predicted_mask = np.argmax(prediction[0], axis=-1)   # <-- this converts softmax to class labels
    ax[i, 2].imshow(predicted_mask, cmap='gray')
    ax[i, 2].set_title('Prediction')

for a in ax.flatten():
    a.axis('off')

fig.suptitle('Results', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# Befor model was not able to predict normal classes correctly.
# and now it is able to predict correct normal classes. our model now is much generalize model than before.

# %%
# Accumulators
from tensorflow.keras.metrics import MeanIoU
from sklearn.metrics import precision_score, recall_score, f1_score
all_preds = []
all_masks = []

# Loop through the full validation dataset
for images, masks in val_ds:
    preds = tuned_unet.predict(images, verbose=0)
    preds_labels = np.argmax(preds, axis=-1)  # (batch_size, H, W)
    masks_labels = np.squeeze(masks, axis=-1)  # (batch_size, H, W)

    all_preds.append(preds_labels)
    all_masks.append(masks_labels)

# Stack everything to single arrays
all_preds = np.concatenate(all_preds, axis=0)
all_masks = np.concatenate(all_masks, axis=0)

# Compute Mean IoU
IOU_keras = MeanIoU(num_classes=3)
IOU_keras.update_state(all_masks, all_preds)
print("Mean IoU =", IOU_keras.result().numpy())

# Flatten for sklearn metrics
y_pred_flat = all_preds.flatten().astype(np.uint8)
y_true_flat = all_masks.flatten().astype(np.uint8)

# Compute precision, recall, F1, Dice (macro averaged)
p = precision_score(y_true_flat, y_pred_flat, average='macro')
r = recall_score(y_true_flat, y_pred_flat, average='macro')
f1 = f1_score(y_true_flat, y_pred_flat, average='macro')
dice = f1  # F1 = Dice in multiclass

print(f'Dice Score (macro) = {dice:.3f}')
print(f'Precision Score = {p:.3f}')
print(f'Recall Score = {r:.3f}')
print(f'F1 Score = {f1:.3f}')
# Out:
# Mean IoU = 0.5514782
# Dice Score (macro) = 0.671
# Precision Score = 0.814
# Recall Score = 0.631
# F1 Score = 0.671

# %% [markdown]
# # Transfer learning of U-Net

# %% [markdown]
# # Here’s how you can replace the encoder with a pretrained model (like VGG16) using Keras:(transfer learning in encoder)
# Since U-Net is built of encoder (downsampling) and decoder (upsampling) parts — transfer learning is typically applied to the encoder part by replacing it with a pretrained model like VGG, ResNet, EfficientNet, etc. These are pretrained on large datasets (like ImageNet), and their feature extraction capabilities can be leveraged here.

# %% [markdown]
# Key Notes:
# - I used VGG16 as a pretrained encoder.
#
# - Replaced your custom encoder with VGG16’s convolutional feature maps.
#
# - Frozen VGG16 layers for initial training (can unfreeze later for fine-tuning).
#
# - Input shape must now be (256, 256, 3) because ImageNet pre-trained models expect 3 channels.
#
# - Decoder and final segmentation output remain your custom design

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Input, add, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

def dice_coefficient(y_true, y_pred, smooth=1):
    y_true = tf.one_hot(tf.squeeze(tf.cast(y_true, tf.int32), axis=-1), 3)
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)

    dice = (2. * intersection + smooth) / (union + smooth)
    return dice


def conv_block(input, num_filters):
    conv = Conv2D(num_filters, (3, 3), activation="relu", padding="same", kernel_initializer='he_normal')(input)
    conv = Conv2D(num_filters, (3, 3), activation="relu", padding="same", kernel_initializer='he_normal')(conv)
    conv = Conv2D(num_filters, (3, 3), activation="relu", padding="same", kernel_initializer='he_normal')(conv)

    return conv


def decoder_block(input, skip_features, num_filters):
    uconv = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    con = concatenate([uconv, skip_features])
    conv = conv_block(con, num_filters)
    return conv

def build_transfer_learning_unet(input_shape=(256, 256, 3), num_classes=3):
    # Load VGG16 pretrained model without top layers
    vgg = VGG16(include_top=False, weights='imagenet', input_shape=input_shape)
    vgg.trainable = False  # Freeze VGG layers

    # Encoder: Using VGG16 feature maps
    s1 = vgg.get_layer("block1_conv2").output  # 256x256x64
    s2 = vgg.get_layer("block2_conv2").output  # 128x128x128
    s3 = vgg.get_layer("block3_conv3").output  # 64x64x256
    s4 = vgg.get_layer("block4_conv3").output  # 32x32x512

    b1 = vgg.get_layer("block5_conv3").output  # 16x16x512

    # Decoder: same as your original
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    output_layer = Conv2D(num_classes, (1, 1), padding="same", activation="softmax")(d4)

    model = Model(inputs=vgg.input, outputs=output_layer, name="TransferLearning_U-Net")
    return model

tl_unet = build_transfer_learning_unet(input_shape=(256, 256, 3), num_classes=3)

tl_unet.compile(loss="sparse_categorical_crossentropy", optimizer="Adam", metrics=["accuracy", dice_coefficient])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Early stopping callback
early_stop = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=10,
    restore_best_weights=True,
    mode='max'
)

# Fit the model
history = tl_unet.fit(
    train_ds,
    validation_data=val_ds,
    batch_size=8,
    epochs=50,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 305s 7s/step - accuracy: 0.8033 - dice_coefficient: 0.7754 - loss: 1.1942 - val_accuracy: 0.9233 - val_dice_coefficient: 0.8814 - val_loss: 0.3356
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.9204 - dice_coefficient: 0.8585 - loss: 0.3195 - val_accuracy: 0.9242 - val_dice_coefficient: 0.8978 - val_loss: 0.2580
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9240 - dice_coefficient: 0.8862 - loss: 0.2411 - val_accuracy: 0.9279 - val_dice_coefficient: 0.9057 - val_loss: 0.2403
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.9245 - dice_coefficient: 0.8896 - loss: 0.2385 - val_accuracy: 0.9237 - val_dice_coefficient: 0.9193 - val_loss: 0.2992
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.9256 - dice_coefficient: 0.8972 - loss: 0.2362 - val_accuracy: 0.9333 - val_dice_coefficient: 0.9089 - val_loss: 0.2136
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.9318 - dice_coefficient: 0.9013 - loss: 0.1988 - val_accuracy: 0.9358 - val_dice_coefficient: 0.9029 - val_loss: 0.1948
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9354 - dice_coefficient: 0.9044 - loss: 0.1827 - val_accuracy: 0.9401 - val_dice_coefficient: 0.9182 - val_loss: 0.1860
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9383 - dice_coefficient: 0.9105 - loss: 0.1793 - val_accuracy: 0.9400 - val_dice_coefficient: 0.9127 - val_loss: 0.1900
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.9390 - dice_coefficient: 0.9086 - loss: 0.1766 - val_accuracy: 0.9411 - val_dice_coefficient: 0.9116 - val_loss: 0.1819
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.9460 - dice_coefficient: 0.9175 - loss: 0.1564 - val_accuracy: 0.9412 - val_dice_coefficient: 0.9120 - val_loss: 0.1805
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9504 - dice_coefficient: 0.9228 - loss: 0.1492 - val_accuracy: 0.9337 - val_dice_coefficient: 0.9051 - val_loss: 0.1895
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9448 - dice_coefficient: 0.9204 - loss: 0.1558 - val_accuracy: 0.9427 - val_dice_coefficient: 0.9258 - val_loss: 0.1894
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9451 - dice_coefficient: 0.9232 - loss: 0.1591 - val_accuracy: 0.9433 - val_dice_coefficient: 0.9346 - val_loss: 0.2123
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.9511 - dice_coefficient: 0.9274 - loss: 0.1472 - val_accuracy: 0.9333 - val_dice_coefficient: 0.9091 - val_loss: 0.1875
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9543 - dice_coefficient: 0.9331 - loss: 0.1320 - val_accuracy: 0.9434 - val_dice_coefficient: 0.9281 - val_loss: 0.1882
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9581 - dice_coefficient: 0.9355 - loss: 0.1234 - val_accuracy: 0.9441 - val_dice_coefficient: 0.9293 - val_loss: 0.1814
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.9609 - dice_coefficient: 0.9418 - loss: 0.1125 - val_accuracy: 0.9453 - val_dice_coefficient: 0.9361 - val_loss: 0.1970
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9654 - dice_coefficient: 0.9487 - loss: 0.1038 - val_accuracy: 0.9332 - val_dice_coefficient: 0.9060 - val_loss: 0.1989
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.9628 - dice_coefficient: 0.9399 - loss: 0.1099 - val_accuracy: 0.9454 - val_dice_coefficient: 0.9320 - val_loss: 0.1906
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9672 - dice_coefficient: 0.9507 - loss: 0.0940 - val_accuracy: 0.9475 - val_dice_coefficient: 0.9368 - val_loss: 0.1950
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.9722 - dice_coefficient: 0.9575 - loss: 0.0808 - val_accuracy: 0.9378 - val_dice_coefficient: 0.9300 - val_loss: 0.2300
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9740 - dice_coefficient: 0.9622 - loss: 0.0760 - val_accuracy: 0.9421 - val_dice_coefficient: 0.9343 - val_loss: 0.2250
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9756 - dice_coefficient: 0.9639 - loss: 0.0697 - val_accuracy: 0.9403 - val_dice_coefficient: 0.9282 - val_loss: 0.2143
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9735 - dice_coefficient: 0.9601 - loss: 0.0787 - val_accuracy: 0.9409 - val_dice_coefficient: 0.9317 - val_loss: 0.2164
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9748 - dice_coefficient: 0.9628 - loss: 0.0729 - val_accuracy: 0.9466 - val_dice_coefficient: 0.9396 - val_loss: 0.2131
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9776 - dice_coefficient: 0.9670 - loss: 0.0633 - val_accuracy: 0.9465 - val_dice_coefficient: 0.9389 - val_loss: 0.2077
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9779 - dice_coefficient: 0.9667 - loss: 0.0634 - val_accuracy: 0.9436 - val_dice_coefficient: 0.9371 - val_loss: 0.2355
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9814 - dice_coefficient: 0.9722 - loss: 0.0522 - val_accuracy: 0.9422 - val_dice_coefficient: 0.9345 - val_loss: 0.2391
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.9796 - dice_coefficient: 0.9699 - loss: 0.0576 - val_accuracy: 0.9465 - val_dice_coefficient: 0.9375 - val_loss: 0.2049
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9801 - dice_coefficient: 0.9708 - loss: 0.0556 - val_accuracy: 0.9488 - val_dice_coefficient: 0.9433 - val_loss: 0.2304
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9843 - dice_coefficient: 0.9773 - loss: 0.0433 - val_accuracy: 0.9479 - val_dice_coefficient: 0.9432 - val_loss: 0.2574
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.9872 - dice_coefficient: 0.9810 - loss: 0.0347 - val_accuracy: 0.9437 - val_dice_coefficient: 0.9362 - val_loss: 0.2459
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.9839 - dice_coefficient: 0.9763 - loss: 0.0440 - val_accuracy: 0.9492 - val_dice_coefficient: 0.9448 - val_loss: 0.2683
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9862 - dice_coefficient: 0.9801 - loss: 0.0371 - val_accuracy: 0.9474 - val_dice_coefficient: 0.9435 - val_loss: 0.2836
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9883 - dice_coefficient: 0.9831 - loss: 0.0307 - val_accuracy: 0.9445 - val_dice_coefficient: 0.9402 - val_loss: 0.2736
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9887 - dice_coefficient: 0.9836 - loss: 0.0302 - val_accuracy: 0.9463 - val_dice_coefficient: 0.9404 - val_loss: 0.2500
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9874 - dice_coefficient: 0.9814 - loss: 0.0339 - val_accuracy: 0.9484 - val_dice_coefficient: 0.9440 - val_loss: 0.2641
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9880 - dice_coefficient: 0.9822 - loss: 0.0314 - val_accuracy: 0.9501 - val_dice_coefficient: 0.9468 - val_loss: 0.2920
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9862 - dice_coefficient: 0.9802 - loss: 0.0363 - val_accuracy: 0.9479 - val_dice_coefficient: 0.9436 - val_loss: 0.2566
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9852 - dice_coefficient: 0.9780 - loss: 0.0397 - val_accuracy: 0.9464 - val_dice_coefficient: 0.9426 - val_loss: 0.2881
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9829 - dice_coefficient: 0.9758 - loss: 0.0463 - val_accuracy: 0.9484 - val_dice_coefficient: 0.9440 - val_loss: 0.2508
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9868 - dice_coefficient: 0.9800 - loss: 0.0359 - val_accuracy: 0.9489 - val_dice_coefficient: 0.9443 - val_loss: 0.2466
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9881 - dice_coefficient: 0.9827 - loss: 0.0309 - val_accuracy: 0.9487 - val_dice_coefficient: 0.9453 - val_loss: 0.2850
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9897 - dice_coefficient: 0.9845 - loss: 0.0260 - val_accuracy: 0.9486 - val_dice_coefficient: 0.9461 - val_loss: 0.3063
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9916 - dice_coefficient: 0.9879 - loss: 0.0210 - val_accuracy: 0.9498 - val_dice_coefficient: 0.9477 - val_loss: 0.3343
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9912 - dice_coefficient: 0.9874 - loss: 0.0224 - val_accuracy: 0.9486 - val_dice_coefficient: 0.9461 - val_loss: 0.3351
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9913 - dice_coefficient: 0.9877 - loss: 0.0221 - val_accuracy: 0.9469 - val_dice_coefficient: 0.9447 - val_loss: 0.3271
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9891 - dice_coefficient: 0.9845 - loss: 0.0289 - val_accuracy: 0.9455 - val_dice_coefficient: 0.9425 - val_loss: 0.3160
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.9915 - dice_coefficient: 0.9876 - loss: 0.0212 - val_accuracy: 0.9458 - val_dice_coefficient: 0.9431 - val_loss: 0.3208
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.9918 - dice_coefficient: 0.9879 - loss: 0.0205 - val_accuracy: 0.9466 - val_dice_coefficient: 0.9446 - val_loss: 0.3464

# %%
tl_unet.save(r"/content/drive/MyDrive/newmodels/tl_unet.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,3))
ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax[0].legend()
ax[1].plot(history.epoch, history.history["accuracy"], label="Train accuracy")
ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation accuracy")
ax[1].legend()
fig.suptitle('Loss and Accuracy', fontsize=16)
plt.show()

# %%
for images, masks in val_ds.take(2):
    break

fig, ax = plt.subplots(5, 3, figsize=(10, 18))

j = np.random.randint(0, images.shape[0], 5)
for i in range(5):
    # Original Image
    ax[i, 0].imshow(np.squeeze(images[j[i]]), cmap='gray')
    ax[i, 0].set_title('Image')

    # Ground Truth Mask
    ax[i, 1].imshow(np.squeeze(masks[j[i]]), cmap='gray')
    ax[i, 1].set_title('Mask')

    # Prediction (argmax to get class indices)
    prediction = tl_unet.predict(np.expand_dims(images[j[i]], 0), verbose=0)
    predicted_mask = np.argmax(prediction[0], axis=-1)   # <-- this converts softmax to class labels
    ax[i, 2].imshow(predicted_mask, cmap='gray')
    ax[i, 2].set_title('Prediction')

for a in ax.flatten():
    a.axis('off')

fig.suptitle('Results', fontsize=16)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.metrics import MeanIoU
import numpy as np

# Accumulate predictions and ground truths
all_preds = []
all_masks = []

# Predict and collect over entire test set
for images, masks in val_ds:
    preds = tl_unet.predict(images, verbose=0)
    preds_labels = np.argmax(preds, axis=-1)
    masks_labels = np.squeeze(masks)

    all_preds.append(preds_labels)
    all_masks.append(masks_labels)

# Concatenate all batches into one array
all_preds = np.concatenate(all_preds, axis=0)
all_masks = np.concatenate(all_masks, axis=0)

# Mean IoU
IOU_keras = MeanIoU(num_classes=3)
IOU_keras.update_state(all_masks, all_preds)
print("Mean IoU =", IOU_keras.result().numpy())

# Flatten for sklearn metrics
y_pred_flat = all_preds.flatten().astype(np.uint8)
y_true_flat = all_masks.flatten().astype(np.uint8)

# Precision, Recall, F1 (macro average)
p = precision_score(y_true_flat, y_pred_flat, average='macro')
r = recall_score(y_true_flat, y_pred_flat, average='macro')
f1 = f1_score(y_true_flat, y_pred_flat, average='macro')

# Dice Score (same as F1 macro for multiclass)
dice = f1_score(y_true_flat, y_pred_flat, average='macro')

print(f'Dice Score (macro) = {dice:.3f}')
print(f'Precision Score = {p:.3f}')
print(f'Recall Score = {r:.3f}')
print(f'F1 Score = {f1:.3f}')
# Out:
# Mean IoU = 0.64007896
# Dice Score (macro) = 0.760
# Precision Score = 0.811
# Recall Score = 0.726
# F1 Score = 0.760

# %% [markdown]
# # U2NET

# %% [markdown]
# U²-Net is originally in PyTorch, but their is no pretrained weights of model are avialble here.
# and also there’s no official U²-Net in Keras.
#
# it means we have to implement the u2net model architecture.
#
# The U²-Net (as introduced in U²-Net: Going Deeper with Nested U-Structure for Salient Object Detection) is a nested U-shaped network inside each stage of the main U-shaped architecture — meaning:
#
# Every stage (both encoder and decoder) contains a Residual U-block (RSU), which is itself a U-Net structure inside that block.
#
# RSUs allow U²-Net to capture both local and global context efficiently by stacking these nested U structures.

# %%
from tensorflow.keras.layers import Activation, UpSampling2D
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Input, add, Dropout, BatchNormalization

# Conv block with residuals and LeakyReLU
def conv_block(inputs, out_ch, rate=1):
    x = Conv2D(out_ch, 3, padding='same', dilation_rate=rate)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def RSU_L(inputs, out_ch, int_ch, num_layers, rate=2):
    x = conv_block(inputs, out_ch)
    init_feats = x
    x = conv_block(x, out_ch)

    # Encoder
    skip = []
    x = conv_block(x, int_ch)
    skip.append(x)

    for i in range(num_layers-2):
        x = MaxPooling2D((2,2))(x)
        x = conv_block(x, int_ch)
        skip.append(x)

    # Bridge
    x = conv_block(x, int_ch, rate=rate)

    # Decoder
    skip.reverse()
    x = concatenate([x, skip[0]])
    x = conv_block(x, int_ch)

    for i in range(num_layers-3):
        x = UpSampling2D((2,2), interpolation="bilinear")(x)
        x = concatenate([x, skip[i+1]])
        x = conv_block(x, int_ch)

    x = UpSampling2D((2,2), interpolation="bilinear")(x)
    x = concatenate([x, skip[-1]])
    x = conv_block(x, out_ch)

    # Add residual connection
    x = add([x, init_feats])

    return x

def RSU_4F(inputs, out_ch, int_ch):
    x0 = conv_block(inputs, out_ch, rate=1)

    # Encoder
    x1 = conv_block(x0, int_ch, rate=1)
    x2 = conv_block(x1, int_ch, rate=2)
    x3 = conv_block(x2, int_ch, rate=4)

    # Bridge
    x4 = conv_block(x3, int_ch, rate=8)

    # Decoder
    x = concatenate([x4, x3])
    x = conv_block(x, int_ch, rate=4)

    x = concatenate([x, x2])
    x = conv_block(x, int_ch, rate=2)

    x = concatenate([x, x1])
    x = conv_block(x, out_ch, rate=1)

    # Add residual connection
    x = add([x, x0])

    return x

def u2net(input_shape, out_ch, int_ch, num_classes=3):
    inputs = Input(input_shape)
    s0 = inputs

    s1 = RSU_L(s0, out_ch[0], int_ch[0], 7)
    p1 = MaxPooling2D((2,2))(s1)

    s2 = RSU_L(p1, out_ch[1], int_ch[1], 6)
    p2 = MaxPooling2D((2,2))(s2)

    s3 = RSU_L(p2, out_ch[2], int_ch[2], 5)
    p3 = MaxPooling2D((2,2))(s3)

    s4 = RSU_L(p3, out_ch[3], int_ch[3], 4)
    p4 = MaxPooling2D((2,2))(s4)

    s5 = RSU_L(p4, out_ch[4], int_ch[4], 3)
    p5 = MaxPooling2D((2,2))(s5)

    # Bridge
    b1 = RSU_4F(p5, out_ch[5], int_ch[5])
    b2 = UpSampling2D((2,2), interpolation="bilinear")(b1)

    # Decoder
    d1 = concatenate([b2, s5])
    d1 = RSU_4F(d1, out_ch[6], int_ch[6])
    u1 = UpSampling2D((2,2), interpolation="bilinear")(d1)

    d2 = concatenate([u1, s4])
    d2 = RSU_4F(d2, out_ch[7], int_ch[7])
    u2 = UpSampling2D((2,2), interpolation="bilinear")(d2)

    d3 = concatenate([u2, s3])
    d3 = RSU_4F(d3, out_ch[8], int_ch[8])
    u3 = UpSampling2D((2,2), interpolation="bilinear")(d3)

    d4 = concatenate([u3, s2])
    d4 = RSU_4F(d4, out_ch[9], int_ch[9])
    u4 = UpSampling2D((2,2), interpolation="bilinear")(d4)

    d5 = concatenate([u4, s1])
    d5 = RSU_4F(d5, out_ch[10], int_ch[10])
    u5 = UpSampling2D((2,2), interpolation="bilinear")(d5)

    # Side outputs
    y1 = Conv2D(num_classes, 3, padding="same")(d5)

    y2 = Conv2D(num_classes, 3, padding="same")(d4)
    y2 = UpSampling2D((2, 2), interpolation="bilinear")(y2)

    y3 = Conv2D(num_classes, 3, padding="same")(d3)
    y3 = UpSampling2D((4, 4), interpolation="bilinear")(y3)

    y4 = Conv2D(num_classes, 3, padding="same")(d2)
    y4 = UpSampling2D((8, 8), interpolation="bilinear")(y4)

    y5 = Conv2D(num_classes, 3, padding="same")(d1)
    y5 = UpSampling2D((16, 16), interpolation="bilinear")(y5)

    y6 = Conv2D(num_classes, 3, padding="same")(b1)
    y6 = UpSampling2D((32, 32), interpolation="bilinear")(y6)

    y0 = concatenate([y1, y2, y3, y4, y5, y6])
    y0 = Conv2D(num_classes, 3, padding="same")(y0)


    # Activation
    y0 = Activation('softmax')(y0)
    y1 = Activation('softmax')(y1)
    y2 = Activation('softmax')(y2)
    y3 = Activation('softmax')(y3)
    y4 = Activation('softmax')(y4)
    y5 = Activation('softmax')(y5)
    y6 = Activation('softmax')(y6)

    model = tf.keras.models.Model(inputs, [y0, y1, y2, y3, y4, y5, y6])
    return model

def build_u2net(input_shape=(256,256,3), num_classes=3):
    out_ch = [64, 64,64,64,64,64,64,64, 64, 64,64]
    int_ch = [16,16,16,16,16,16,16,16,16,16,16]

    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model

if __name__ == "__main__":
    u2net = build_u2net()
    u2net.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 256, 256,  │      1,792 │ input_layer_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_51[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 256, 256,  │     36,928 │ activation_18[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_52[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 256, 256,  │      9,232 │ activation_19[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_53[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 128, 128,  │          0 │ activation_20[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 128, 128,  │      2,320 │ max_pooling2d_8[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_54[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 64, 64,    │          0 │ activation_21[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 64, 64,    │      2,320 │ max_pooling2d_9[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         64 │ conv2d_55[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_10    │ (None, 32, 32,    │          0 │ activation_22[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 32, 32,    │      2,320 │ max_pooling2d_10… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_56[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_11    │ (None, 16, 16,    │          0 │ activation_23[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 16, 16,    │      2,320 │ max_pooling2d_11… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ conv2d_57[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_12    │ (None, 8, 8, 16)  │          0 │ activation_24[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 8, 8, 16)  │      2,320 │ max_pooling2d_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_58[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 8, 8, 16)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 8, 8, 16)  │      2,320 │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_59[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 8, 8, 16)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 8, 8, 32)  │          0 │ activation_26[0]… │
# │ (Concatenate)       │                   │            │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_60 (Conv2D)  │ (None, 8, 8, 16)  │      4,624 │ concatenate_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_60[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 8, 8, 16)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 16, 16,    │          0 │ activation_27[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 16, 16,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 32)               │            │ activation_24[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_61 (Conv2D)  │ (None, 16, 16,    │      4,624 │ concatenate_13[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ conv2d_61[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 32, 32,    │          0 │ activation_28[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 32, 32,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 32)               │            │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_62 (Conv2D)  │ (None, 32, 32,    │      4,624 │ concatenate_14[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_62[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 64, 64,    │          0 │ activation_29[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 64, 64,    │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 32)               │            │ activation_22[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_63 (Conv2D)  │ (None, 64, 64,    │      4,624 │ concatenate_15[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         64 │ conv2d_63[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 128, 128,  │          0 │ activation_30[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 128, 128,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 32)               │            │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_64 (Conv2D)  │ (None, 128, 128,  │      4,624 │ concatenate_16[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_64[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 256, 256,  │          0 │ activation_31[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 256, 256,  │          0 │ up_sampling2d_4[… │
# │ (Concatenate)       │ 32)               │            │ activation_20[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_65 (Conv2D)  │ (None, 256, 256,  │     18,496 │ concatenate_17[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_65[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 256, 256,  │          0 │ activation_32[0]… │
# │                     │ 64)               │            │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_13    │ (None, 128, 128,  │          0 │ add[0][0]         │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_66 (Conv2D)  │ (None, 128, 128,  │     36,928 │ max_pooling2d_13… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_66[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_67 (Conv2D)  │ (None, 128, 128,  │     36,928 │ activation_33[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_67[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_68 (Conv2D)  │ (None, 128, 128,  │      9,232 │ activation_34[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_68[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_14    │ (None, 64, 64,    │          0 │ activation_35[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_69 (Conv2D)  │ (None, 64, 64,    │      2,320 │ max_pooling2d_14… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         64 │ conv2d_69[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_15    │ (None, 32, 32,    │          0 │ activation_36[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_70 (Conv2D)  │ (None, 32, 32,    │      2,320 │ max_pooling2d_15… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_70[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_16    │ (None, 16, 16,    │          0 │ activation_37[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_71 (Conv2D)  │ (None, 16, 16,    │      2,320 │ max_pooling2d_16… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ conv2d_71[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_17    │ (None, 8, 8, 16)  │          0 │ activation_38[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_72 (Conv2D)  │ (None, 8, 8, 16)  │      2,320 │ max_pooling2d_17… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_72[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 8, 8, 16)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_73 (Conv2D)  │ (None, 8, 8, 16)  │      2,320 │ activation_39[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_73[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 8, 8, 16)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 8, 8, 32)  │          0 │ activation_40[0]… │
# │ (Concatenate)       │                   │            │ activation_39[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_74 (Conv2D)  │ (None, 8, 8, 16)  │      4,624 │ concatenate_18[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_74[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 8, 8, 16)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 16, 16,    │          0 │ activation_41[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 16, 16,    │          0 │ up_sampling2d_5[… │
# │ (Concatenate)       │ 32)               │            │ activation_38[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_75 (Conv2D)  │ (None, 16, 16,    │      4,624 │ concatenate_19[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ conv2d_75[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 32, 32,    │          0 │ activation_42[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 32, 32,    │          0 │ up_sampling2d_6[… │
# │ (Concatenate)       │ 32)               │            │ activation_37[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_76 (Conv2D)  │ (None, 32, 32,    │      4,624 │ concatenate_20[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_76[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 64, 64,    │          0 │ activation_43[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_21      │ (None, 64, 64,    │          0 │ up_sampling2d_7[… │
# │ (Concatenate)       │ 32)               │            │ activation_36[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_77 (Conv2D)  │ (None, 64, 64,    │      4,624 │ concatenate_21[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         64 │ conv2d_77[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_8     │ (None, 128, 128,  │          0 │ activation_44[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_22      │ (None, 128, 128,  │          0 │ up_sampling2d_8[… │
# │ (Concatenate)       │ 32)               │            │ activation_35[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_78 (Conv2D)  │ (None, 128, 128,  │     18,496 │ concatenate_22[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_78[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 128, 128,  │          0 │ activation_45[0]… │
# │                     │ 64)               │            │ activation_33[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_18    │ (None, 64, 64,    │          0 │ add_1[0][0]       │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_79 (Conv2D)  │ (None, 64, 64,    │     36,928 │ max_pooling2d_18… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_79[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_80 (Conv2D)  │ (None, 64, 64,    │     36,928 │ activation_46[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_80[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_81 (Conv2D)  │ (None, 64, 64,    │      9,232 │ activation_47[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         64 │ conv2d_81[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 32, 32,    │          0 │ activation_48[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_82 (Conv2D)  │ (None, 32, 32,    │      2,320 │ max_pooling2d_19… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_82[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 16, 16,    │          0 │ activation_49[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_83 (Conv2D)  │ (None, 16, 16,    │      2,320 │ max_pooling2d_20… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ conv2d_83[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_50       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_21    │ (None, 8, 8, 16)  │          0 │ activation_50[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_84 (Conv2D)  │ (None, 8, 8, 16)  │      2,320 │ max_pooling2d_21… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_84[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 8, 8, 16)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_85 (Conv2D)  │ (None, 8, 8, 16)  │      2,320 │ activation_51[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_85[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 8, 8, 16)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, 8, 8, 32)  │          0 │ activation_52[0]… │
# │ (Concatenate)       │                   │            │ activation_51[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_86 (Conv2D)  │ (None, 8, 8, 16)  │      4,624 │ concatenate_23[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_86[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 8, 8, 16)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_9     │ (None, 16, 16,    │          0 │ activation_53[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_24      │ (None, 16, 16,    │          0 │ up_sampling2d_9[… │
# │ (Concatenate)       │ 32)               │            │ activation_50[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_87 (Conv2D)  │ (None, 16, 16,    │      4,624 │ concatenate_24[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ conv2d_87[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_10    │ (None, 32, 32,    │          0 │ activation_54[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_25      │ (None, 32, 32,    │          0 │ up_sampling2d_10… │
# │ (Concatenate)       │ 32)               │            │ activation_49[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_88 (Conv2D)  │ (None, 32, 32,    │      4,624 │ concatenate_25[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_88[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_11    │ (None, 64, 64,    │          0 │ activation_55[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_26      │ (None, 64, 64,    │          0 │ up_sampling2d_11… │
# │ (Concatenate)       │ 32)               │            │ activation_48[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_89 (Conv2D)  │ (None, 64, 64,    │     18,496 │ concatenate_26[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_89[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 64, 64,    │          0 │ activation_56[0]… │
# │                     │ 64)               │            │ activation_46[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_22    │ (None, 32, 32,    │          0 │ add_2[0][0]       │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_90 (Conv2D)  │ (None, 32, 32,    │     36,928 │ max_pooling2d_22… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_90[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_91 (Conv2D)  │ (None, 32, 32,    │     36,928 │ activation_57[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_91[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 32, 32,    │      9,232 │ activation_58[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_92[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_23    │ (None, 16, 16,    │          0 │ activation_59[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, 16, 16,    │      2,320 │ max_pooling2d_23… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ conv2d_93[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_60       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_24    │ (None, 8, 8, 16)  │          0 │ activation_60[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 8, 8, 16)  │      2,320 │ max_pooling2d_24… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_94[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_61       │ (None, 8, 8, 16)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_95 (Conv2D)  │ (None, 8, 8, 16)  │      2,320 │ activation_61[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_95[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_62       │ (None, 8, 8, 16)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_27      │ (None, 8, 8, 32)  │          0 │ activation_62[0]… │
# │ (Concatenate)       │                   │            │ activation_61[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_96 (Conv2D)  │ (None, 8, 8, 16)  │      4,624 │ concatenate_27[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_96[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_63       │ (None, 8, 8, 16)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_12    │ (None, 16, 16,    │          0 │ activation_63[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_28      │ (None, 16, 16,    │          0 │ up_sampling2d_12… │
# │ (Concatenate)       │ 32)               │            │ activation_60[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_97 (Conv2D)  │ (None, 16, 16,    │      4,624 │ concatenate_28[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ conv2d_97[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_64       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_13    │ (None, 32, 32,    │          0 │ activation_64[0]… │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_29      │ (None, 32, 32,    │          0 │ up_sampling2d_13… │
# │ (Concatenate)       │ 32)               │            │ activation_59[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_98 (Conv2D)  │ (None, 32, 32,    │     18,496 │ concatenate_29[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_98[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_65       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 32, 32,    │          0 │ activation_65[0]… │
# │                     │ 64)               │            │ activation_57[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_25    │ (None, 16, 16,    │          0 │ add_3[0][0]       │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_99 (Conv2D)  │ (None, 16, 16,    │     36,928 │ max_pooling2d_25… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_99[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_66       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_100 (Conv2D) │ (None, 16, 16,    │     36,928 │ activation_66[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_100[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_67       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_101 (Conv2D) │ (None, 16, 16,    │      9,232 │ activation_67[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ conv2d_101[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_68       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_26    │ (None, 8, 8, 16)  │          0 │ activation_68[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_102 (Conv2D) │ (None, 8, 8, 16)  │      2,320 │ max_pooling2d_26… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 16)  │         64 │ conv2d_102[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_141[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_108      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_142 (Conv2D) │ (None, 128, 128,  │      2,320 │ activation_108[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_142[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_109      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_48      │ (None, 128, 128,  │          0 │ activation_109[0… │
# │ (Concatenate)       │ 32)               │            │ activation_108[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_143 (Conv2D) │ (None, 128, 128,  │      4,624 │ concatenate_48[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_143[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_110      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_49      │ (None, 128, 128,  │          0 │ activation_110[0… │
# │ (Concatenate)       │ 32)               │            │ activation_107[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_144 (Conv2D) │ (None, 128, 128,  │      4,624 │ concatenate_49[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_144[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_111      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_50      │ (None, 128, 128,  │          0 │ activation_111[0… │
# │ (Concatenate)       │ 32)               │            │ activation_106[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_145 (Conv2D) │ (None, 128, 128,  │     18,496 │ concatenate_50[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_145[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_112      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 128, 128,  │          0 │ activation_112[0… │
# │                     │ 64)               │            │ activation_105[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_19    │ (None, 256, 256,  │          0 │ add_9[0][0]       │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_51      │ (None, 256, 256,  │          0 │ up_sampling2d_19… │
# │ (Concatenate)       │ 128)              │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_146 (Conv2D) │ (None, 256, 256,  │     73,792 │ concatenate_51[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_146[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_113      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_147 (Conv2D) │ (None, 256, 256,  │      9,232 │ activation_113[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_147[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_114      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_148 (Conv2D) │ (None, 256, 256,  │      2,320 │ activation_114[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_148[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_115      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_149 (Conv2D) │ (None, 256, 256,  │      2,320 │ activation_115[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_149[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_116      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_150 (Conv2D) │ (None, 256, 256,  │      2,320 │ activation_116[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_150[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_117      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_52      │ (None, 256, 256,  │          0 │ activation_117[0… │
# │ (Concatenate)       │ 32)               │            │ activation_116[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_151 (Conv2D) │ (None, 256, 256,  │      4,624 │ concatenate_52[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_151[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_118      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_53      │ (None, 256, 256,  │          0 │ activation_118[0… │
# │ (Concatenate)       │ 32)               │            │ activation_115[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_152 (Conv2D) │ (None, 256, 256,  │      4,624 │ concatenate_53[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_152[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_119      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_54      │ (None, 256, 256,  │          0 │ activation_119[0… │
# │ (Concatenate)       │ 32)               │            │ activation_114[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_153 (Conv2D) │ (None, 256, 256,  │     18,496 │ concatenate_54[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_153[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_120      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 256, 256,  │          0 │ activation_120[0… │
# │                     │ 64)               │            │ activation_113[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_155 (Conv2D) │ (None, 128, 128,  │      1,731 │ add_9[0][0]       │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_156 (Conv2D) │ (None, 64, 64, 3) │      1,731 │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_157 (Conv2D) │ (None, 32, 32, 3) │      1,731 │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_158 (Conv2D) │ (None, 16, 16, 3) │      1,731 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_159 (Conv2D) │ (None, 8, 8, 3)   │      1,731 │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_154 (Conv2D) │ (None, 256, 256,  │      1,731 │ add_10[0][0]      │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_21    │ (None, 256, 256,  │          0 │ conv2d_155[0][0]  │
# │ (UpSampling2D)      │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_22    │ (None, 256, 256,  │          0 │ conv2d_156[0][0]  │
# │ (UpSampling2D)      │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_23    │ (None, 256, 256,  │          0 │ conv2d_157[0][0]  │
# │ (UpSampling2D)      │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_24    │ (None, 256, 256,  │          0 │ conv2d_158[0][0]  │
# │ (UpSampling2D)      │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_25    │ (None, 256, 256,  │          0 │ conv2d_159[0][0]  │
# │ (UpSampling2D)      │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_55      │ (None, 256, 256,  │          0 │ conv2d_154[0][0], │
# │ (Concatenate)       │ 18)               │            │ up_sampling2d_21… │
# │                     │                   │            │ up_sampling2d_22… │
# │                     │                   │            │ up_sampling2d_23… │
# │                     │                   │            │ up_sampling2d_24… │
# │                     │                   │            │ up_sampling2d_25… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_160 (Conv2D) │ (None, 256, 256,  │        489 │ concatenate_55[0… │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_121      │ (None, 256, 256,  │          0 │ conv2d_160[0][0]  │
# │ (Activation)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_122      │ (None, 256, 256,  │          0 │ conv2d_154[0][0]  │
# │ (Activation)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_123      │ (None, 256, 256,  │          0 │ up_sampling2d_21… │
# │ (Activation)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_124      │ (None, 256, 256,  │          0 │ up_sampling2d_22… │
# │ (Activation)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_125      │ (None, 256, 256,  │          0 │ up_sampling2d_23… │
# │ (Activation)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_126      │ (None, 256, 256,  │          0 │ up_sampling2d_24… │
# │ (Activation)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_127      │ (None, 256, 256,  │          0 │ up_sampling2d_25… │
# │ (Activation)        │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,280,699 (4.89 MB)
#  Trainable params: 1,274,811 (4.86 MB)
#  Non-trainable params: 5,888 (23.00 KB)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Compile the model — same loss and metrics for each output
losses = {f'activation_{i}': 'categorical_crossentropy' for i in range(7)}
metrics = {f'activation_{i}': 'accuracy' for i in range(7)}

# Prepare supervised labels (deep supervision)
y_train_multi = [y_train] * 7
y_val_multi   = [y_val] * 7

# Compile the model (since you're using integer masks)
u2net.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=['sparse_categorical_crossentropy'] * 7,
    metrics=['accuracy'] * 7
)

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model
history = u2net.fit(
    x=X_train,
    y=y_train_multi,
    validation_data=(X_val, y_val_multi),
    epochs=50,
    batch_size=8,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 243s 1s/step - activation_103_accuracy: 0.6372 - activation_103_loss: 0.8655 - activation_104_accuracy: 0.5900 - activation_104_loss: 1.0088 - activation_105_accuracy: 0.8711 - activation_105_loss: 0.5151 - activation_106_accuracy: 0.4395 - activation_106_loss: 1.2557 - activation_107_accuracy: 0.2452 - activation_107_loss: 2.0347 - activation_108_accuracy: 0.8684 - activation_108_loss: 0.5532 - activation_109_accuracy: 0.3283 - activation_109_loss: 1.5252 - loss: 7.7582 - val_activation_103_accuracy: 0.9240 - val_activation_103_loss: 0.5074 - val_activation_104_accuracy: 0.9233 - val_activation_104_loss: 0.5228 - val_activation_105_accuracy: 0.9244 - val_activation_105_loss: 0.5105 - val_activation_106_accuracy: 0.9243 - val_activation_106_loss: 0.6243 - val_activation_107_accuracy: 0.9094 - val_activation_107_loss: 0.6812 - val_activation_108_accuracy: 0.9244 - val_activation_108_loss: 0.4278 - val_activation_109_accuracy: 0.9194 - val_activation_109_loss: 0.7221 - val_loss: 3.9960
# Epoch 2/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 73s 460ms/step - activation_103_accuracy: 0.9227 - activation_103_loss: 0.2934 - activation_104_accuracy: 0.9233 - activation_104_loss: 0.2959 - activation_105_accuracy: 0.9242 - activation_105_loss: 0.2740 - activation_106_accuracy: 0.9225 - activation_106_loss: 0.2977 - activation_107_accuracy: 0.9188 - activation_107_loss: 0.3246 - activation_108_accuracy: 0.9244 - activation_108_loss: 0.2734 - activation_109_accuracy: 0.9212 - activation_109_loss: 0.3196 - loss: 2.0786 - val_activation_103_accuracy: 0.9243 - val_activation_103_loss: 0.3761 - val_activation_104_accuracy: 0.9243 - val_activation_104_loss: 0.3929 - val_activation_105_accuracy: 0.9244 - val_activation_105_loss: 0.3985 - val_activation_106_accuracy: 0.9244 - val_activation_106_loss: 0.4155 - val_activation_107_accuracy: 0.8814 - val_activation_107_loss: 0.5171 - val_activation_108_accuracy: 0.9244 - val_activation_108_loss: 0.3870 - val_activation_109_accuracy: 0.9159 - val_activation_109_loss: 0.4360 - val_loss: 2.9226
# Epoch 3/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 455ms/step - activation_103_accuracy: 0.9272 - activation_103_loss: 0.2413 - activation_104_accuracy: 0.9273 - activation_104_loss: 0.2448 - activation_105_accuracy: 0.9288 - activation_105_loss: 0.2341 - activation_106_accuracy: 0.9269 - activation_106_loss: 0.2409 - activation_107_accuracy: 0.9257 - activation_107_loss: 0.2467 - activation_108_accuracy: 0.9272 - activation_108_loss: 0.2441 - activation_109_accuracy: 0.9262 - activation_109_loss: 0.2655 - loss: 1.7174 - val_activation_103_accuracy: 0.9243 - val_activation_103_loss: 0.3616 - val_activation_104_accuracy: 0.9241 - val_activation_104_loss: 0.3360 - val_activation_105_accuracy: 0.9244 - val_activation_105_loss: 0.3599 - val_activation_106_accuracy: 0.9241 - val_activation_106_loss: 0.4059 - val_activation_107_accuracy: 0.8635 - val_activation_107_loss: 0.4669 - val_activation_108_accuracy: 0.9144 - val_activation_108_loss: 0.3910 - val_activation_109_accuracy: 0.8844 - val_activation_109_loss: 0.3762 - val_loss: 2.6972
# Epoch 4/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 38s 484ms/step - activation_103_accuracy: 0.9277 - activation_103_loss: 0.2230 - activation_104_accuracy: 0.9271 - activation_104_loss: 0.2265 - activation_105_accuracy: 0.9311 - activation_105_loss: 0.2164 - activation_106_accuracy: 0.9269 - activation_106_loss: 0.2216 - activation_107_accuracy: 0.9306 - activation_107_loss: 0.2244 - activation_108_accuracy: 0.9292 - activation_108_loss: 0.2288 - activation_109_accuracy: 0.9257 - activation_109_loss: 0.2457 - loss: 1.5863 - val_activation_103_accuracy: 0.8974 - val_activation_103_loss: 0.3712 - val_activation_104_accuracy: 0.9022 - val_activation_104_loss: 0.3177 - val_activation_105_accuracy: 0.8918 - val_activation_105_loss: 0.3712 - val_activation_106_accuracy: 0.7748 - val_activation_106_loss: 0.4847 - val_activation_107_accuracy: 0.7919 - val_activation_107_loss: 0.5302 - val_activation_108_accuracy: 0.7984 - val_activation_108_loss: 0.4804 - val_activation_109_accuracy: 0.8543 - val_activation_109_loss: 0.3936 - val_loss: 2.9503
# Epoch 5/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 39s 454ms/step - activation_103_accuracy: 0.9357 - activation_103_loss: 0.1966 - activation_104_accuracy: 0.9309 - activation_104_loss: 0.2150 - activation_105_accuracy: 0.9342 - activation_105_loss: 0.2033 - activation_106_accuracy: 0.9341 - activation_106_loss: 0.2056 - activation_107_accuracy: 0.9354 - activation_107_loss: 0.2032 - activation_108_accuracy: 0.9353 - activation_108_loss: 0.1994 - activation_109_accuracy: 0.9312 - activation_109_loss: 0.2198 - loss: 1.4430 - val_activation_103_accuracy: 0.8656 - val_activation_103_loss: 0.3899 - val_activation_104_accuracy: 0.9086 - val_activation_104_loss: 0.3276 - val_activation_105_accuracy: 0.8469 - val_activation_105_loss: 0.4034 - val_activation_106_accuracy: 0.7604 - val_activation_106_loss: 0.5046 - val_activation_107_accuracy: 0.7380 - val_activation_107_loss: 0.5522 - val_activation_108_accuracy: 0.7285 - val_activation_108_loss: 0.5744 - val_activation_109_accuracy: 0.8115 - val_activation_109_loss: 0.4604 - val_loss: 3.2025
# Epoch 6/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 454ms/step - activation_103_accuracy: 0.9445 - activation_103_loss: 0.1699 - activation_104_accuracy: 0.9411 - activation_104_loss: 0.1812 - activation_105_accuracy: 0.9441 - activation_105_loss: 0.1747 - activation_106_accuracy: 0.9432 - activation_106_loss: 0.1779 - activation_107_accuracy: 0.9443 - activation_107_loss: 0.1747 - activation_108_accuracy: 0.9428 - activation_108_loss: 0.1745 - activation_109_accuracy: 0.9388 - activation_109_loss: 0.1947 - loss: 1.2476 - val_activation_103_accuracy: 0.9187 - val_activation_103_loss: 0.2622 - val_activation_104_accuracy: 0.9155 - val_activation_104_loss: 0.2626 - val_activation_105_accuracy: 0.9100 - val_activation_105_loss: 0.2644 - val_activation_106_accuracy: 0.9019 - val_activation_106_loss: 0.2889 - val_activation_107_accuracy: 0.9029 - val_activation_107_loss: 0.2996 - val_activation_108_accuracy: 0.8995 - val_activation_108_loss: 0.3164 - val_activation_109_accuracy: 0.9065 - val_activation_109_loss: 0.2935 - val_loss: 1.9859
# Epoch 7/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 458ms/step - activation_103_accuracy: 0.9409 - activation_103_loss: 0.1737 - activation_104_accuracy: 0.9372 - activation_104_loss: 0.1880 - activation_105_accuracy: 0.9391 - activation_105_loss: 0.1806 - activation_106_accuracy: 0.9393 - activation_106_loss: 0.1808 - activation_107_accuracy: 0.9401 - activation_107_loss: 0.1770 - activation_108_accuracy: 0.9395 - activation_108_loss: 0.1786 - activation_109_accuracy: 0.9367 - activation_109_loss: 0.1966 - loss: 1.2753 - val_activation_103_accuracy: 0.9247 - val_activation_103_loss: 0.2306 - val_activation_104_accuracy: 0.9280 - val_activation_104_loss: 0.2136 - val_activation_105_accuracy: 0.9269 - val_activation_105_loss: 0.2165 - val_activation_106_accuracy: 0.9234 - val_activation_106_loss: 0.2275 - val_activation_107_accuracy: 0.9200 - val_activation_107_loss: 0.2416 - val_activation_108_accuracy: 0.9150 - val_activation_108_loss: 0.2628 - val_activation_109_accuracy: 0.9189 - val_activation_109_loss: 0.2646 - val_loss: 1.6460
# Epoch 8/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 453ms/step - activation_103_accuracy: 0.9467 - activation_103_loss: 0.1572 - activation_104_accuracy: 0.9428 - activation_104_loss: 0.1708 - activation_105_accuracy: 0.9447 - activation_105_loss: 0.1638 - activation_106_accuracy: 0.9449 - activation_106_loss: 0.1633 - activation_107_accuracy: 0.9456 - activation_107_loss: 0.1626 - activation_108_accuracy: 0.9439 - activation_108_loss: 0.1640 - activation_109_accuracy: 0.9409 - activation_109_loss: 0.1785 - loss: 1.1601 - val_activation_103_accuracy: 0.9306 - val_activation_103_loss: 0.2114 - val_activation_104_accuracy: 0.9227 - val_activation_104_loss: 0.2185 - val_activation_105_accuracy: 0.9253 - val_activation_105_loss: 0.2162 - val_activation_106_accuracy: 0.9281 - val_activation_106_loss: 0.2157 - val_activation_107_accuracy: 0.9181 - val_activation_107_loss: 0.2396 - val_activation_108_accuracy: 0.9233 - val_activation_108_loss: 0.2292 - val_activation_109_accuracy: 0.9223 - val_activation_109_loss: 0.2381 - val_loss: 1.5593
# Epoch 9/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 455ms/step - activation_103_accuracy: 0.9496 - activation_103_loss: 0.1482 - activation_104_accuracy: 0.9467 - activation_104_loss: 0.1596 - activation_105_accuracy: 0.9481 - activation_105_loss: 0.1551 - activation_106_accuracy: 0.9485 - activation_106_loss: 0.1549 - activation_107_accuracy: 0.9485 - activation_107_loss: 0.1535 - activation_108_accuracy: 0.9480 - activation_108_loss: 0.1542 - activation_109_accuracy: 0.9423 - activation_109_loss: 0.1749 - loss: 1.1005 - val_activation_103_accuracy: 0.9388 - val_activation_103_loss: 0.1985 - val_activation_104_accuracy: 0.9389 - val_activation_104_loss: 0.1948 - val_activation_105_accuracy: 0.9370 - val_activation_105_loss: 0.1978 - val_activation_106_accuracy: 0.9387 - val_activation_106_loss: 0.2023 - val_activation_107_accuracy: 0.9399 - val_activation_107_loss: 0.1961 - val_activation_108_accuracy: 0.9369 - val_activation_108_loss: 0.2161 - val_activation_109_accuracy: 0.9361 - val_activation_109_loss: 0.2117 - val_loss: 1.4082
# Epoch 10/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 455ms/step - activation_103_accuracy: 0.9504 - activation_103_loss: 0.1468 - activation_104_accuracy: 0.9449 - activation_104_loss: 0.1622 - activation_105_accuracy: 0.9468 - activation_105_loss: 0.1566 - activation_106_accuracy: 0.9480 - activation_106_loss: 0.1558 - activation_107_accuracy: 0.9483 - activation_107_loss: 0.1524 - activation_108_accuracy: 0.9482 - activation_108_loss: 0.1507 - activation_109_accuracy: 0.9433 - activation_109_loss: 0.1714 - loss: 1.0960 - val_activation_103_accuracy: 0.9378 - val_activation_103_loss: 0.1861 - val_activation_104_accuracy: 0.9346 - val_activation_104_loss: 0.1901 - val_activation_105_accuracy: 0.9370 - val_activation_105_loss: 0.1854 - val_activation_106_accuracy: 0.9371 - val_activation_106_loss: 0.1869 - val_activation_107_accuracy: 0.9321 - val_activation_107_loss: 0.1941 - val_activation_108_accuracy: 0.9325 - val_activation_108_loss: 0.1965 - val_activation_109_accuracy: 0.9263 - val_activation_109_loss: 0.2179 - val_loss: 1.3472
# Epoch 11/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 454ms/step - activation_103_accuracy: 0.9540 - activation_103_loss: 0.1320 - activation_104_accuracy: 0.9491 - activation_104_loss: 0.1481 - activation_105_accuracy: 0.9519 - activation_105_loss: 0.1404 - activation_106_accuracy: 0.9524 - activation_106_loss: 0.1391 - activation_107_accuracy: 0.9529 - activation_107_loss: 0.1381 - activation_108_accuracy: 0.9523 - activation_108_loss: 0.1385 - activation_109_accuracy: 0.9486 - activation_109_loss: 0.1539 - loss: 0.9902 - val_activation_103_accuracy: 0.9409 - val_activation_103_loss: 0.1807 - val_activation_104_accuracy: 0.9428 - val_activation_104_loss: 0.1766 - val_activation_105_accuracy: 0.9405 - val_activation_105_loss: 0.1809 - val_activation_106_accuracy: 0.9415 - val_activation_106_loss: 0.1798 - val_activation_107_accuracy: 0.9392 - val_activation_107_loss: 0.1829 - val_activation_108_accuracy: 0.9397 - val_activation_108_loss: 0.1848 - val_activation_109_accuracy: 0.9352 - val_activation_109_loss: 0.1973 - val_loss: 1.2657
# Epoch 12/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 35s 452ms/step - activation_103_accuracy: 0.9578 - activation_103_loss: 0.1201 - activation_104_accuracy: 0.9546 - activation_104_loss: 0.1322 - activation_105_accuracy: 0.9552 - activation_105_loss: 0.1278 - activation_106_accuracy: 0.9557 - activation_106_loss: 0.1262 - activation_107_accuracy: 0.9566 - activation_107_loss: 0.1242 - activation_108_accuracy: 0.9566 - activation_108_loss: 0.1250 - activation_109_accuracy: 0.9505 - activation_109_loss: 0.1459 - loss: 0.9015 - val_activation_103_accuracy: 0.9413 - val_activation_103_loss: 0.1844 - val_activation_104_accuracy: 0.9405 - val_activation_104_loss: 0.1808 - val_activation_105_accuracy: 0.9424 - val_activation_105_loss: 0.1810 - val_activation_106_accuracy: 0.9426 - val_activation_106_loss: 0.1818 - val_activation_107_accuracy: 0.9419 - val_activation_107_loss: 0.1842 - val_activation_108_accuracy: 0.9382 - val_activation_108_loss: 0.1940 - val_activation_109_accuracy: 0.9378 - val_activation_109_loss: 0.1950 - val_loss: 1.2916
# Epoch 13/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 454ms/step - activation_103_accuracy: 0.9572 - activation_103_loss: 0.1196 - activation_104_accuracy: 0.9548 - activation_104_loss: 0.1292 - activation_105_accuracy: 0.9555 - activation_105_loss: 0.1260 - activation_106_accuracy: 0.9558 - activation_106_loss: 0.1252 - activation_107_accuracy: 0.9555 - activation_107_loss: 0.1241 - activation_108_accuracy: 0.9544 - activation_108_loss: 0.1258 - activation_109_accuracy: 0.9487 - activation_109_loss: 0.1481 - loss: 0.8979 - val_activation_103_accuracy: 0.9442 - val_activation_103_loss: 0.1705 - val_activation_104_accuracy: 0.9459 - val_activation_104_loss: 0.1636 - val_activation_105_accuracy: 0.9436 - val_activation_105_loss: 0.1708 - val_activation_106_accuracy: 0.9415 - val_activation_106_loss: 0.1706 - val_activation_107_accuracy: 0.9406 - val_activation_107_loss: 0.1758 - val_activation_108_accuracy: 0.9389 - val_activation_108_loss: 0.1800 - val_activation_109_accuracy: 0.9322 - val_activation_109_loss: 0.1947 - val_loss: 1.2155
# Epoch 14/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 454ms/step - activation_103_accuracy: 0.9630 - activation_103_loss: 0.1084 - activation_104_accuracy: 0.9611 - activation_104_loss: 0.1156 - activation_105_accuracy: 0.9622 - activation_105_loss: 0.1128 - activation_106_accuracy: 0.9617 - activation_106_loss: 0.1130 - activation_107_accuracy: 0.9614 - activation_107_loss: 0.1131 - activation_108_accuracy: 0.9589 - activation_108_loss: 0.1182 - activation_109_accuracy: 0.9537 - activation_109_loss: 0.1385 - loss: 0.8197 - val_activation_103_accuracy: 0.9456 - val_activation_103_loss: 0.1796 - val_activation_104_accuracy: 0.9465 - val_activation_104_loss: 0.1734 - val_activation_105_accuracy: 0.9465 - val_activation_105_loss: 0.1743 - val_activation_106_accuracy: 0.9449 - val_activation_106_loss: 0.1764 - val_activation_107_accuracy: 0.9427 - val_activation_107_loss: 0.1798 - val_activation_108_accuracy: 0.9424 - val_activation_108_loss: 0.1839 - val_activation_109_accuracy: 0.9362 - val_activation_109_loss: 0.1907 - val_loss: 1.2456
# Epoch 15/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 43s 485ms/step - activation_103_accuracy: 0.9662 - activation_103_loss: 0.0966 - activation_104_accuracy: 0.9627 - activation_104_loss: 0.1073 - activation_105_accuracy: 0.9646 - activation_105_loss: 0.1021 - activation_106_accuracy: 0.9654 - activation_106_loss: 0.1012 - activation_107_accuracy: 0.9655 - activation_107_loss: 0.1003 - activation_108_accuracy: 0.9643 - activation_108_loss: 0.1026 - activation_109_accuracy: 0.9588 - activation_109_loss: 0.1229 - loss: 0.7329 - val_activation_103_accuracy: 0.9139 - val_activation_103_loss: 0.2415 - val_activation_104_accuracy: 0.9103 - val_activation_104_loss: 0.2441 - val_activation_105_accuracy: 0.9090 - val_activation_105_loss: 0.2444 - val_activation_106_accuracy: 0.9078 - val_activation_106_loss: 0.2510 - val_activation_107_accuracy: 0.9084 - val_activation_107_loss: 0.2560 - val_activation_108_accuracy: 0.9119 - val_activation_108_loss: 0.2400 - val_activation_109_accuracy: 0.9204 - val_activation_109_loss: 0.2189 - val_loss: 1.6927
# Epoch 16/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 39s 454ms/step - activation_103_accuracy: 0.9592 - activation_103_loss: 0.1181 - activation_104_accuracy: 0.9576 - activation_104_loss: 0.1255 - activation_105_accuracy: 0.9581 - activation_105_loss: 0.1228 - activation_106_accuracy: 0.9585 - activation_106_loss: 0.1216 - activation_107_accuracy: 0.9578 - activation_107_loss: 0.1215 - activation_108_accuracy: 0.9573 - activation_108_loss: 0.1236 - activation_109_accuracy: 0.9514 - activation_109_loss: 0.1434 - loss: 0.8766 - val_activation_103_accuracy: 0.9448 - val_activation_103_loss: 0.1740 - val_activation_104_accuracy: 0.9421 - val_activation_104_loss: 0.1734 - val_activation_105_accuracy: 0.9431 - val_activation_105_loss: 0.1724 - val_activation_106_accuracy: 0.9394 - val_activation_106_loss: 0.1816 - val_activation_107_accuracy: 0.9426 - val_activation_107_loss: 0.1749 - val_activation_108_accuracy: 0.9411 - val_activation_108_loss: 0.1787 - val_activation_109_accuracy: 0.9378 - val_activation_109_loss: 0.1845 - val_loss: 1.2362
# Epoch 17/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 455ms/step - activation_103_accuracy: 0.9661 - activation_103_loss: 0.0930 - activation_104_accuracy: 0.9643 - activation_104_loss: 0.0999 - activation_105_accuracy: 0.9651 - activation_105_loss: 0.0976 - activation_106_accuracy: 0.9654 - activation_106_loss: 0.0975 - activation_107_accuracy: 0.9654 - activation_107_loss: 0.0973 - activation_108_accuracy: 0.9629 - activation_108_loss: 0.1021 - activation_109_accuracy: 0.9541 - activation_109_loss: 0.1294 - loss: 0.7169 - val_activation_103_accuracy: 0.9520 - val_activation_103_loss: 0.1821 - val_activation_104_accuracy: 0.9551 - val_activation_104_loss: 0.1674 - val_activation_105_accuracy: 0.9556 - val_activation_105_loss: 0.1672 - val_activation_106_accuracy: 0.9533 - val_activation_106_loss: 0.1654 - val_activation_107_accuracy: 0.9513 - val_activation_107_loss: 0.1671 - val_activation_108_accuracy: 0.9470 - val_activation_108_loss: 0.1760 - val_activation_109_accuracy: 0.9440 - val_activation_109_loss: 0.1821 - val_loss: 1.1970
# Epoch 18/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 455ms/step - activation_103_accuracy: 0.9685 - activation_103_loss: 0.0880 - activation_104_accuracy: 0.9667 - activation_104_loss: 0.0952 - activation_105_accuracy: 0.9677 - activation_105_loss: 0.0926 - activation_106_accuracy: 0.9678 - activation_106_loss: 0.0919 - activation_107_accuracy: 0.9675 - activation_107_loss: 0.0917 - activation_108_accuracy: 0.9659 - activation_108_loss: 0.0950 - activation_109_accuracy: 0.9590 - activation_109_loss: 0.1185 - loss: 0.6730 - val_activation_103_accuracy: 0.9420 - val_activation_103_loss: 0.1673 - val_activation_104_accuracy: 0.9429 - val_activation_104_loss: 0.1636 - val_activation_105_accuracy: 0.9436 - val_activation_105_loss: 0.1610 - val_activation_106_accuracy: 0.9416 - val_activation_106_loss: 0.1639 - val_activation_107_accuracy: 0.9422 - val_activation_107_loss: 0.1646 - val_activation_108_accuracy: 0.9415 - val_activation_108_loss: 0.1666 - val_activation_109_accuracy: 0.9353 - val_activation_109_loss: 0.1814 - val_loss: 1.1633
# Epoch 19/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 35s 454ms/step - activation_103_accuracy: 0.9674 - activation_103_loss: 0.0899 - activation_104_accuracy: 0.9653 - activation_104_loss: 0.0982 - activation_105_accuracy: 0.9661 - activation_105_loss: 0.0949 - activation_106_accuracy: 0.9667 - activation_106_loss: 0.0939 - activation_107_accuracy: 0.9665 - activation_107_loss: 0.0942 - activation_108_accuracy: 0.9647 - activation_108_loss: 0.0979 - activation_109_accuracy: 0.9584 - activation_109_loss: 0.1209 - loss: 0.6899 - val_activation_103_accuracy: 0.9468 - val_activation_103_loss: 0.1714 - val_activation_104_accuracy: 0.9467 - val_activation_104_loss: 0.1668 - val_activation_105_accuracy: 0.9470 - val_activation_105_loss: 0.1655 - val_activation_106_accuracy: 0.9462 - val_activation_106_loss: 0.1644 - val_activation_107_accuracy: 0.9462 - val_activation_107_loss: 0.1649 - val_activation_108_accuracy: 0.9454 - val_activation_108_loss: 0.1648 - val_activation_109_accuracy: 0.9404 - val_activation_109_loss: 0.1726 - val_loss: 1.1690
# Epoch 20/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 35s 452ms/step - activation_103_accuracy: 0.9703 - activation_103_loss: 0.0830 - activation_104_accuracy: 0.9686 - activation_104_loss: 0.0880 - activation_105_accuracy: 0.9696 - activation_105_loss: 0.0848 - activation_106_accuracy: 0.9695 - activation_106_loss: 0.0860 - activation_107_accuracy: 0.9695 - activation_107_loss: 0.0847 - activation_108_accuracy: 0.9675 - activation_108_loss: 0.0901 - activation_109_accuracy: 0.9605 - activation_109_loss: 0.1140 - loss: 0.6306 - val_activation_103_accuracy: 0.9521 - val_activation_103_loss: 0.2116 - val_activation_104_accuracy: 0.9529 - val_activation_104_loss: 0.1950 - val_activation_105_accuracy: 0.9521 - val_activation_105_loss: 0.2063 - val_activation_106_accuracy: 0.9521 - val_activation_106_loss: 0.2001 - val_activation_107_accuracy: 0.9493 - val_activation_107_loss: 0.1984 - val_activation_108_accuracy: 0.9486 - val_activation_108_loss: 0.2014 - val_activation_109_accuracy: 0.9437 - val_activation_109_loss: 0.1936 - val_loss: 1.3958
# Epoch 21/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 454ms/step - activation_103_accuracy: 0.9726 - activation_103_loss: 0.0750 - activation_104_accuracy: 0.9698 - activation_104_loss: 0.0832 - activation_105_accuracy: 0.9710 - activation_105_loss: 0.0798 - activation_106_accuracy: 0.9712 - activation_106_loss: 0.0797 - activation_107_accuracy: 0.9712 - activation_107_loss: 0.0796 - activation_108_accuracy: 0.9696 - activation_108_loss: 0.0839 - activation_109_accuracy: 0.9623 - activation_109_loss: 0.1065 - loss: 0.5879 - val_activation_103_accuracy: 0.9427 - val_activation_103_loss: 0.1869 - val_activation_104_accuracy: 0.9481 - val_activation_104_loss: 0.1678 - val_activation_105_accuracy: 0.9461 - val_activation_105_loss: 0.1727 - val_activation_106_accuracy: 0.9439 - val_activation_106_loss: 0.1769 - val_activation_107_accuracy: 0.9407 - val_activation_107_loss: 0.1867 - val_activation_108_accuracy: 0.9401 - val_activation_108_loss: 0.1874 - val_activation_109_accuracy: 0.9376 - val_activation_109_loss: 0.1881 - val_loss: 1.2662
# Epoch 22/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 453ms/step - activation_103_accuracy: 0.9739 - activation_103_loss: 0.0700 - activation_104_accuracy: 0.9728 - activation_104_loss: 0.0766 - activation_105_accuracy: 0.9735 - activation_105_loss: 0.0740 - activation_106_accuracy: 0.9736 - activation_106_loss: 0.0730 - activation_107_accuracy: 0.9734 - activation_107_loss: 0.0730 - activation_108_accuracy: 0.9715 - activation_108_loss: 0.0778 - activation_109_accuracy: 0.9650 - activation_109_loss: 0.0992 - loss: 0.5436 - val_activation_103_accuracy: 0.9510 - val_activation_103_loss: 0.1717 - val_activation_104_accuracy: 0.9517 - val_activation_104_loss: 0.1628 - val_activation_105_accuracy: 0.9522 - val_activation_105_loss: 0.1617 - val_activation_106_accuracy: 0.9517 - val_activation_106_loss: 0.1622 - val_activation_107_accuracy: 0.9495 - val_activation_107_loss: 0.1686 - val_activation_108_accuracy: 0.9480 - val_activation_108_loss: 0.1690 - val_activation_109_accuracy: 0.9443 - val_activation_109_loss: 0.1741 - val_loss: 1.1672
# Epoch 23/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - activation_103_accuracy: 0.9726 - activation_103_loss: 0.0720 - activation_104_accuracy: 0.9710 - activation_104_loss: 0.0783 - activation_105_accuracy: 0.9720 - activation_105_loss: 0.0753 - activation_106_accuracy: 0.9725 - activation_106_loss: 0.0754 - activation_107_accuracy: 0.9722 - activation_107_loss: 0.0749 - activation_108_accuracy: 0.9699 - activation_108_loss: 0.0806 - activation_109_accuracy: 0.9624 - activation_109_loss: 0.1045 - loss: 0.5610

# %%
u2net.save(r"/content/drive/MyDrive/VIRUS/U2Net")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(history.history.keys())
# Out:
# dict_keys(['activation_103_accuracy', 'activation_103_loss', 'activation_104_accuracy', 'activation_104_loss', 'activation_105_accuracy', 'activation_105_loss', 'activation_106_accuracy', 'activation_106_loss', 'activation_107_accuracy', 'activation_107_loss', 'activation_108_accuracy', 'activation_108_loss', 'activation_109_accuracy', 'activation_109_loss', 'loss', 'val_activation_103_accuracy', 'val_activation_103_loss', 'val_activation_104_accuracy', 'val_activation_104_loss', 'val_activation_105_accuracy', 'val_activation_105_loss', 'val_activation_106_accuracy', 'val_activation_106_loss', 'val_activation_107_accuracy', 'val_activation_107_loss', 'val_activation_108_accuracy', 'val_activation_108_loss', 'val_activation_109_accuracy', 'val_activation_109_loss', 'val_loss'])

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(12, 4))

# Loss plot
ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax[0].legend()
ax[0].set_title("Total Loss")

# Accuracy plot — for final output 'activation_109'
ax[1].plot(history.epoch, history.history["activation_109_accuracy"], label="Train accuracy")
ax[1].plot(history.epoch, history.history["val_activation_109_accuracy"], label="Validation accuracy")
ax[1].legend()
ax[1].set_title("Final Output Accuracy (activation_109)")

fig.suptitle('Loss and Accuracy over Epochs', fontsize=16)
plt.show()

# %% [markdown]
# # Prediction with u2net

# %%
for images, masks in val_ds.take(2):
    break

fig, ax = plt.subplots(5, 3, figsize=(10, 18))

j = np.random.randint(0, images.shape[0], 5)
for i in range(5):
    # Original Image
    ax[i, 0].imshow(np.squeeze(images[j[i]]), cmap='gray')
    ax[i, 0].set_title('Image')

    # Ground Truth Mask
    ax[i, 1].imshow(np.squeeze(masks[j[i]]), cmap='gray')
    ax[i, 1].set_title('Mask')

    # Prediction (argmax to get class indices)
    prediction = u2net.predict(np.expand_dims(images[j[i]], 0), verbose=0)
    predicted_mask = np.argmax(prediction[0], axis=-1)   # <-- this converts softmax to class labels
    ax[i, 2].imshow(np.squeeze(predicted_mask), cmap='gray')  # <-- Squeeze to remove the extra dimension
    ax[i, 2].set_title('Prediction')

for a in ax.flatten():
    a.axis('off')

fig.suptitle('Results', fontsize=16)
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.metrics import MeanIoU
from sklearn.metrics import precision_score, recall_score, f1_score
all_preds = []
all_masks = []

for images, masks in val_ds:
    y_pred = u2net.predict(images, verbose=0)
    y_pred_final = y_pred[-1]  # Final output

    y_pred_labels = np.argmax(y_pred_final, axis=-1)   # (batch, 256, 256)
    y_test_labels = np.squeeze(masks, axis=-1)         # (batch, 256, 256)

    # Ensure shapes match before stacking
    assert y_pred_labels.shape == y_test_labels.shape, f"Shape mismatch: {y_pred_labels.shape} vs {y_test_labels.shape}"

    all_preds.append(y_pred_labels)
    all_masks.append(y_test_labels)

# Concatenate
all_preds = np.concatenate(all_preds, axis=0)
all_masks = np.concatenate(all_masks, axis=0)

# Mean IoU
IOU_keras = MeanIoU(num_classes=3)
IOU_keras.update_state(all_masks, all_preds)
print("Mean IoU =", IOU_keras.result().numpy())

# Flatten for sklearn metrics
y_pred_flat = all_preds.flatten().astype(np.uint8)
y_true_flat = all_masks.flatten().astype(np.uint8)

# Precision, Recall, F1 (macro average)
p = precision_score(y_true_flat, y_pred_flat, average='macro')
r = recall_score(y_true_flat, y_pred_flat, average='macro')
f1 = f1_score(y_true_flat, y_pred_flat, average='macro')

# Dice Score (same as F1 macro for multiclass)
dice = f1_score(y_true_flat, y_pred_flat, average='macro')

print(f'Dice Score (macro) = {dice:.3f}')
print(f'Precision Score = {p:.3f}')
print(f'Recall Score = {r:.3f}')
print(f'F1 Score = {f1:.3f}')

print('Pred shape:', all_preds.shape)
print('GT shape:', all_masks.shape)
# Out:
# Mean IoU = 0.4220182
# Dice Score (macro) = 0.506
# Precision Score = 0.767
# Recall Score = 0.452
# F1 Score = 0.506
# Pred shape: (155, 256, 256)
# GT shape: (155, 256, 256)

# %% [markdown]
# **Our dataset is less and noisy**
#
# U-Net tends to generalize better on limited or noisy datasets
# — because it’s simpler, has fewer parameters, and is less likely to overfit. It focuses on capturing the core spatial features without getting distracted by noise.
#
# U²-Net, especially the full version, shines on large, diverse, or high-detail datasets
# — where its nested U-structures and multi-scale supervision can capture finer, more complex patterns. But on limited/noisy data, its extra complexity can actually hurt generalization, making it prone to overfitting

# %% [markdown]
# # DeepLabV3+ Replication with MobileNetV2 Backbone (Keras)

# %% [markdown]
# This implementation replicates the DeepLabV3+ architecture using TensorFlow Keras, with MobileNetV2 as the backbone for feature extraction. It's customized for semantic segmentation tasks with support for arbitrary number of classes (default is 4).

# %%
# !git clone --depth 1 https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 4351, done.
# remote: Counting objects: 100% (4351/4351), done.
# remote: Compressing objects: 100% (3261/3261), done.
# remote: Total 4351 (delta 1171), reused 2921 (delta 1017), pack-reused 0 (from 0)
# Receiving objects: 100% (4351/4351), 53.73 MiB | 31.22 MiB/s, done.
# Resolving deltas: 100% (1171/1171), done.

# %%
# !pip install -q tf-slim

# %%
import tensorflow as tf
from tensorflow.keras import layers

def DeepLabV3Plus(num_classes=4, input_shape=(224, 224, 3)):
    # Use the recommended input shape to load the pretrained weights properly.
    base_model = tf.keras.applications.MobileNetV2(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )

    # Get the high-level feature map from the last layer of the bottleneck.
    high_level_feature = base_model.get_layer('block_13_expand_relu').output  # Expected shape: (14, 14, 576)
    # Apply a convolution (ASPP-like) to adjust the number of filters.
    x = layers.Conv2D(256, 3, padding="same", dilation_rate=6, activation='relu')(high_level_feature)
    x = layers.BatchNormalization()(x)

    # Upsample high-level features from 14x14 to 56x56 (scale factor 4)
    x = layers.UpSampling2D(size=(4, 4), interpolation='bilinear')(x)  # Now shape: (56,56,256)

    # Get low-level features from an earlier layer.
    low_level_feature = base_model.get_layer('block_3_expand_relu').output   # Expected shape: (56, 56, 144)
    low_level_feature = layers.Conv2D(48, 1, padding="same", activation='relu')(low_level_feature)
    low_level_feature = layers.BatchNormalization()(low_level_feature)

    # Now both tensors are (56,56) spatially—concatenate along the channel dimension.
    x = layers.Concatenate()([x, low_level_feature])  # Shape becomes (56, 56, 256+48 = 304)

    # Decoder: refine the features with a couple of conv layers.
    x = layers.Conv2D(256, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(256, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)

    # Upsample the features back to the input spatial resolution (224x224)
    x = layers.UpSampling2D(size=(4, 4), interpolation='bilinear')(x)  # (56*4 = 224)

    # Final 1x1 conv layer to produce segmentation logits
    outputs = layers.Conv2D(num_classes, kernel_size=1, activation='softmax')(x)

    model = tf.keras.Model(inputs=base_model.input, outputs=outputs)
    return model

# %% [markdown]
# # Compilation

# %%
NUM_CLASSES = 3
deepLab = DeepLabV3Plus(num_classes=NUM_CLASSES + 1, input_shape=(256, 256, 3))

deepLab.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# deepLab.summary()
# Out:
# <ipython-input-28-efddd59149e6>:6: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = deepLab.fit(train_ds, validation_data=val_ds, epochs=50,callbacks=[early_stop])
# Out:
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 160s 3s/step - accuracy: 0.3602 - loss: 1.5809 - val_accuracy: 0.1847 - val_loss: 1.4306
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 728ms/step - accuracy: 0.7900 - loss: 1.0451 - val_accuracy: 0.7500 - val_loss: 1.1706
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 773ms/step - accuracy: 0.9303 - loss: 0.6302 - val_accuracy: 0.8808 - val_loss: 0.7220
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 764ms/step - accuracy: 0.9509 - loss: 0.4784 - val_accuracy: 0.9155 - val_loss: 0.5112
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 723ms/step - accuracy: 0.9578 - loss: 0.4088 - val_accuracy: 0.9252 - val_loss: 0.4020
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 727ms/step - accuracy: 0.9660 - loss: 0.3324 - val_accuracy: 0.9257 - val_loss: 0.3580
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 729ms/step - accuracy: 0.9711 - loss: 0.2534 - val_accuracy: 0.9253 - val_loss: 0.3493
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 724ms/step - accuracy: 0.9741 - loss: 0.2311 - val_accuracy: 0.9254 - val_loss: 0.3566
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 777ms/step - accuracy: 0.9770 - loss: 0.1920 - val_accuracy: 0.9249 - val_loss: 0.3464
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 774ms/step - accuracy: 0.9789 - loss: 0.1859 - val_accuracy: 0.9255 - val_loss: 0.3411
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 752ms/step - accuracy: 0.9823 - loss: 0.1456 - val_accuracy: 0.9259 - val_loss: 0.3357
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 757ms/step - accuracy: 0.9811 - loss: 0.1469 - val_accuracy: 0.9263 - val_loss: 0.3409
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 766ms/step - accuracy: 0.9849 - loss: 0.1114 - val_accuracy: 0.9252 - val_loss: 0.3562
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 776ms/step - accuracy: 0.9867 - loss: 0.0999 - val_accuracy: 0.9254 - val_loss: 0.3704
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 717ms/step - accuracy: 0.9871 - loss: 0.0849 - val_accuracy: 0.9248 - val_loss: 0.3700
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 718ms/step - accuracy: 0.9870 - loss: 0.0921 - val_accuracy: 0.9256 - val_loss: 0.3494
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 745ms/step - accuracy: 0.9879 - loss: 0.0784 - val_accuracy: 0.9267 - val_loss: 0.3639
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 721ms/step - accuracy: 0.9897 - loss: 0.0707 - val_accuracy: 0.9266 - val_loss: 0.3527
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 744ms/step - accuracy: 0.9901 - loss: 0.0687 - val_accuracy: 0.9263 - val_loss: 0.3615
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 723ms/step - accuracy: 0.9907 - loss: 0.0622 - val_accuracy: 0.9259 - val_loss: 0.3657
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 713ms/step - accuracy: 0.9906 - loss: 0.0596 - val_accuracy: 0.9259 - val_loss: 0.3600

# %%
# early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# history = deepLab.fit(train_ds, validation_data=val_ds, epochs=50,callbacks=[early_stop])
# Out:
# Epoch 1/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.3592 - loss: 1.5942 - val_accuracy: 0.9067 - val_loss: 0.9861
# Epoch 2/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 378ms/step - accuracy: 0.7920 - loss: 1.0507 - val_accuracy: 0.8749 - val_loss: 0.7967
# Epoch 3/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 380ms/step - accuracy: 0.9286 - loss: 0.6020 - val_accuracy: 0.8818 - val_loss: 0.6078
# Epoch 4/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 380ms/step - accuracy: 0.9433 - loss: 0.4239 - val_accuracy: 0.9050 - val_loss: 0.4779
# Epoch 5/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 380ms/step - accuracy: 0.9546 - loss: 0.3236 - val_accuracy: 0.9126 - val_loss: 0.4271
# Epoch 6/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 378ms/step - accuracy: 0.9593 - loss: 0.2749 - val_accuracy: 0.9150 - val_loss: 0.3927
# Epoch 7/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 378ms/step - accuracy: 0.9646 - loss: 0.2420 - val_accuracy: 0.9153 - val_loss: 0.3732
# Epoch 8/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 377ms/step - accuracy: 0.9688 - loss: 0.2025 - val_accuracy: 0.9154 - val_loss: 0.3702
# Epoch 9/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 375ms/step - accuracy: 0.9721 - loss: 0.1728 - val_accuracy: 0.9152 - val_loss: 0.3770
# Epoch 10/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 377ms/step - accuracy: 0.9747 - loss: 0.1573 - val_accuracy: 0.9157 - val_loss: 0.3643
# Epoch 11/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 376ms/step - accuracy: 0.9771 - loss: 0.1399 - val_accuracy: 0.9155 - val_loss: 0.3704
# Epoch 12/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 376ms/step - accuracy: 0.9800 - loss: 0.1220 - val_accuracy: 0.9159 - val_loss: 0.3793
# Epoch 13/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 376ms/step - accuracy: 0.9812 - loss: 0.1099 - val_accuracy: 0.9159 - val_loss: 0.3753
# Epoch 14/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 377ms/step - accuracy: 0.9836 - loss: 0.0982 - val_accuracy: 0.9165 - val_loss: 0.3810
# Epoch 15/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 376ms/step - accuracy: 0.9837 - loss: 0.0922 - val_accuracy: 0.9170 - val_loss: 0.3712
# Epoch 16/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 375ms/step - accuracy: 0.9850 - loss: 0.0838 - val_accuracy: 0.9176 - val_loss: 0.3820
# Epoch 17/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 375ms/step - accuracy: 0.9873 - loss: 0.0734 - val_accuracy: 0.9179 - val_loss: 0.3819
# Epoch 18/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 374ms/step - accuracy: 0.9881 - loss: 0.0674 - val_accuracy: 0.9183 - val_loss: 0.3812
# Epoch 19/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 375ms/step - accuracy: 0.9890 - loss: 0.0617 - val_accuracy: 0.9177 - val_loss: 0.3865
# Epoch 20/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 375ms/step - accuracy: 0.9898 - loss: 0.0542 - val_accuracy: 0.9182 - val_loss: 0.3856

# %%
deepLab.save(r"C:\Users\drimr\Desktop\FYP Bachelors\FYP Ultrasound\Code and Data\deepLab.h5")

# %%
loss, acc = deepLab.evaluate(val_ds)
print(f"Validation Loss: {loss:.4f}")
print(f"Validation Accuracy: {acc:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - accuracy: 0.9308 - loss: 0.3152
# Validation Loss: 0.3357
# Validation Accuracy: 0.9259

# %% [markdown]
# # Visualizing results

# %%
import matplotlib.pyplot as plt

# Get one sample from the validation set
for image, true_mask in val_ds.take(1):
    break

# Predict the mask
pred = deepLab.predict(tf.expand_dims(image[0], axis=0))  # Add batch
pred_mask = tf.argmax(pred[0], axis=-1)              # Remove batch, get class per pixel
pred_mask = tf.expand_dims(pred_mask, axis=-1)       # For visualization

# Plotting everything
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(image[0])
plt.title("Original Image")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(true_mask[0], cmap="gray")
plt.title("Ground Truth Mask")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(pred_mask, cmap="gray")
plt.title("Predicted Mask")
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,3))
ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax[0].legend()
ax[1].plot(history.epoch, history.history["accuracy"], label="Train accuracy")
ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation accuracy")
ax[1].legend()
fig.suptitle('Loss and Accuracy', fontsize=16)
plt.show()

# %%
for images, masks in val_ds.take(2):
    break

fig, ax = plt.subplots(5, 3, figsize=(10, 18))

j = np.random.randint(0, images.shape[0], 5)
for i in range(5):
    # Original Image
    ax[i, 0].imshow(np.squeeze(images[j[i]]), cmap='gray')
    ax[i, 0].set_title('Image')

    # Ground Truth Mask
    ax[i, 1].imshow(np.squeeze(masks[j[i]]), cmap='gray')
    ax[i, 1].set_title('Mask')

    # Prediction (argmax to get class indices)
    prediction = deepLab.predict(np.expand_dims(images[j[i]], 0), verbose=0)
    predicted_mask = np.argmax(prediction[0], axis=-1)   # <-- this converts softmax to class labels
    ax[i, 2].imshow(np.squeeze(predicted_mask), cmap='gray')  # <-- Squeeze to remove the extra dimension
    ax[i, 2].set_title('Prediction')

for a in ax.flatten():
    a.axis('off')

fig.suptitle('Results', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Scores / Evaluation Metrics

# %%
# Accumulators
from tensorflow.keras.metrics import MeanIoU
from sklearn.metrics import precision_score, recall_score, f1_score
all_preds = []
all_masks = []

# Loop through the full validation dataset
for images, masks in val_ds:
    preds = deepLab.predict(images, verbose=0)
    preds_labels = np.argmax(preds, axis=-1)  # (batch_size, H, W)
    masks_labels = np.squeeze(masks, axis=-1)  # (batch_size, H, W)

    all_preds.append(preds_labels)
    all_masks.append(masks_labels)

# Stack everything to single arrays
all_preds = np.concatenate(all_preds, axis=0)
all_masks = np.concatenate(all_masks, axis=0)

# Compute Mean IoU
IOU_keras = MeanIoU(num_classes=3)
IOU_keras.update_state(all_masks, all_preds)
print("Mean IoU =", IOU_keras.result().numpy())

# Flatten for sklearn metrics
y_pred_flat = all_preds.flatten().astype(np.uint8)
y_true_flat = all_masks.flatten().astype(np.uint8)

# Compute precision, recall, F1, Dice (macro averaged)
p = precision_score(y_true_flat, y_pred_flat, average='macro')
r = recall_score(y_true_flat, y_pred_flat, average='macro')
f1 = f1_score(y_true_flat, y_pred_flat, average='macro')
dice = f1  # F1 = Dice in multiclass

print(f'Dice Score (macro) = {dice:.3f}')
print(f'Precision Score = {p:.3f}')
print(f'Recall Score = {r:.3f}')
print(f'F1 Score = {f1:.3f}')
# Out:
# Mean IoU = 0.3317634
# Dice Score (macro) = 0.364
# Precision Score = 0.750
# Recall Score = 0.357
# F1 Score = 0.364

# %% [markdown]
# # SegNet Architecture in Keras

# %% [markdown]
# This is a custom Keras implementation of the SegNet architecture—a fully convolutional encoder-decoder network designed for semantic segmentation. It’s particularly effective for pixel-wise labeling tasks and works well with relatively small datasets thanks to its simpler structure compared to other modern architectures like DeepLab.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def SegNet(input_shape=(256, 256, 3), num_classes=4):  # 3 classes + background
    inputs = layers.Input(shape=input_shape)

    # ---------- Encoder ----------
    # Block 1
    x = layers.Conv2D(64, 3, padding="same", activation='relu')(inputs)
    x = layers.Conv2D(64, 3, padding="same", activation='relu')(x)
    x = layers.MaxPooling2D()(x)  # 128x128

    # Block 2
    x = layers.Conv2D(128, 3, padding="same", activation='relu')(x)
    x = layers.Conv2D(128, 3, padding="same", activation='relu')(x)
    x = layers.MaxPooling2D()(x)  # 64x64

    # Block 3
    x = layers.Conv2D(256, 3, padding="same", activation='relu')(x)
    x = layers.Conv2D(256, 3, padding="same", activation='relu')(x)
    x = layers.MaxPooling2D()(x)  # 32x32

    # ---------- Decoder ----------
    # Block 3
    x = layers.UpSampling2D()(x)
    x = layers.Conv2D(256, 3, padding="same", activation='relu')(x)
    x = layers.Conv2D(256, 3, padding="same", activation='relu')(x)

    # Block 2
    x = layers.UpSampling2D()(x)
    x = layers.Conv2D(128, 3, padding="same", activation='relu')(x)
    x = layers.Conv2D(128, 3, padding="same", activation='relu')(x)

    # Block 1
    x = layers.UpSampling2D()(x)
    x = layers.Conv2D(64, 3, padding="same", activation='relu')(x)
    x = layers.Conv2D(64, 3, padding="same", activation='relu')(x)

    # Final segmentation layer
    outputs = layers.Conv2D(num_classes, 1, activation='softmax')(x)

    return models.Model(inputs, outputs)

# %% [markdown]
# # Models summary + Compilation

# %%
segnet = SegNet(input_shape=(256, 256, 3), num_classes=4)  # assuming you remapped masks
segnet.compile(tf.keras.optimizers.Adam(1e-4),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
segnet.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 256, 256, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 256, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 128, 128, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 128, 128, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 64, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 64, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_3 (UpSampling2D)  │ (None, 128, 128, 256)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 128, 128, 128)  │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 128, 128, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_4 (UpSampling2D)  │ (None, 256, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 256, 256, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 256, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 256, 256, 4)    │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,879,172 (10.98 MB)
#  Trainable params: 2,879,172 (10.98 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
segnet.fit(train_ds, validation_data=val_ds, epochs=50, callbacks=[early_stop])
# Out:
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 176s 4s/step - accuracy: 0.8105 - loss: 1.0452 - val_accuracy: 0.9233 - val_loss: 0.4462
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9228 - loss: 0.3988 - val_accuracy: 0.9233 - val_loss: 0.3361
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9219 - loss: 0.3272 - val_accuracy: 0.9233 - val_loss: 0.3145
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9214 - loss: 0.3087 - val_accuracy: 0.9233 - val_loss: 0.3041
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9213 - loss: 0.3016 - val_accuracy: 0.9233 - val_loss: 0.3157
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9218 - loss: 0.2971 - val_accuracy: 0.9233 - val_loss: 0.2894
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9222 - loss: 0.2853 - val_accuracy: 0.9233 - val_loss: 0.2831
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9259 - loss: 0.2734 - val_accuracy: 0.9233 - val_loss: 0.2791
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9283 - loss: 0.2682 - val_accuracy: 0.9233 - val_loss: 0.2796
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9215 - loss: 0.2729 - val_accuracy: 0.9233 - val_loss: 0.2735
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9218 - loss: 0.2743 - val_accuracy: 0.9233 - val_loss: 0.3068
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9229 - loss: 0.2807 - val_accuracy: 0.9234 - val_loss: 0.2821
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9183 - loss: 0.2846 - val_accuracy: 0.9261 - val_loss: 0.2601
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9226 - loss: 0.2628 - val_accuracy: 0.9268 - val_loss: 0.2528
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9225 - loss: 0.2614 - val_accuracy: 0.9273 - val_loss: 0.2537
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9255 - loss: 0.2531 - val_accuracy: 0.9266 - val_loss: 0.2589
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9260 - loss: 0.2517 - val_accuracy: 0.9282 - val_loss: 0.2494
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9285 - loss: 0.2329 - val_accuracy: 0.9284 - val_loss: 0.2498
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9220 - loss: 0.2529 - val_accuracy: 0.9286 - val_loss: 0.2431
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9258 - loss: 0.2485 - val_accuracy: 0.9280 - val_loss: 0.2624
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9278 - loss: 0.2432 - val_accuracy: 0.9286 - val_loss: 0.2521
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9259 - loss: 0.2415 - val_accuracy: 0.9291 - val_loss: 0.2410
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9280 - loss: 0.2334 - val_accuracy: 0.9286 - val_loss: 0.2385
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9320 - loss: 0.2229 - val_accuracy: 0.9301 - val_loss: 0.2484
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9244 - loss: 0.2523 - val_accuracy: 0.9292 - val_loss: 0.2407
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9289 - loss: 0.2287 - val_accuracy: 0.9299 - val_loss: 0.2341
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9285 - loss: 0.2278 - val_accuracy: 0.9300 - val_loss: 0.2474
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9292 - loss: 0.2304 - val_accuracy: 0.9304 - val_loss: 0.2360
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9292 - loss: 0.2297 - val_accuracy: 0.9307 - val_loss: 0.2246
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9305 - loss: 0.2216 - val_accuracy: 0.9313 - val_loss: 0.2242
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9323 - loss: 0.2143 - val_accuracy: 0.9315 - val_loss: 0.2258
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9295 - loss: 0.2242 - val_accuracy: 0.9303 - val_loss: 0.2387
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9269 - loss: 0.2334 - val_accuracy: 0.9313 - val_loss: 0.2319
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9297 - loss: 0.2218 - val_accuracy: 0.9311 - val_loss: 0.2249
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9299 - loss: 0.2187 - val_accuracy: 0.9322 - val_loss: 0.2236
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9325 - loss: 0.2146 - val_accuracy: 0.9317 - val_loss: 0.2358
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9278 - loss: 0.2295 - val_accuracy: 0.9320 - val_loss: 0.2234
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9338 - loss: 0.2096 - val_accuracy: 0.9296 - val_loss: 0.2226
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9345 - loss: 0.2099 - val_accuracy: 0.9324 - val_loss: 0.2227
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9305 - loss: 0.2173 - val_accuracy: 0.9324 - val_loss: 0.2250
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9309 - loss: 0.2182 - val_accuracy: 0.9323 - val_loss: 0.2230
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9404 - loss: 0.1961 - val_accuracy: 0.9320 - val_loss: 0.2292
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9336 - loss: 0.2067 - val_accuracy: 0.9328 - val_loss: 0.2197
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9363 - loss: 0.2007 - val_accuracy: 0.9328 - val_loss: 0.2246
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9338 - loss: 0.2115 - val_accuracy: 0.9343 - val_loss: 0.2133
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9355 - loss: 0.2025 - val_accuracy: 0.9348 - val_loss: 0.2154
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9351 - loss: 0.2014 - val_accuracy: 0.9326 - val_loss: 0.2149
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9324 - loss: 0.2123 - val_accuracy: 0.9324 - val_loss: 0.2205
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9347 - loss: 0.2044 - val_accuracy: 0.9316 - val_loss: 0.2450
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9337 - loss: 0.2064 - val_accuracy: 0.9348 - val_loss: 0.2143

# %%
segnet.save(r"C:\Users\drimr\Desktop\FYP Bachelors\FYP Ultrasound\Code and Data\segnet.h5")

# %%
loss, acc = segnet.evaluate(val_ds)
print(f"Validation Loss: {loss:.4f}")
print(f"Validation Accuracy: {acc:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 332ms/step - accuracy: 0.9396 - loss: 0.1950
# Validation Loss: 0.2133
# Validation Accuracy: 0.9343

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt

# Get one sample from the validation set
for image, true_mask in val_ds.take(1):
    break

# Predict the mask
pred = segnet.predict(tf.expand_dims(image[0], axis=0))  # Add batch
pred_mask = tf.argmax(pred[0], axis=-1)              # Remove batch, get class per pixel
pred_mask = tf.expand_dims(pred_mask, axis=-1)       # For visualization

# Plotting everything
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(image[0])
plt.title("Original Image")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(true_mask[0], cmap="gray")
plt.title("Ground Truth Mask")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(pred_mask, cmap="gray")
plt.title("Predicted Mask")
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
for images, masks in val_ds.take(2):
    break

fig, ax = plt.subplots(5, 3, figsize=(10, 18))

j = np.random.randint(0, images.shape[0], 5)
for i in range(5):
    # Original Image
    ax[i, 0].imshow(np.squeeze(images[j[i]]), cmap='gray')
    ax[i, 0].set_title('Image')

    # Ground Truth Mask
    ax[i, 1].imshow(np.squeeze(masks[j[i]]), cmap='gray')
    ax[i, 1].set_title('Mask')

    # Prediction (argmax to get class indices)
    prediction = segnet.predict(np.expand_dims(images[j[i]], 0), verbose=0)
    predicted_mask = np.argmax(prediction[0], axis=-1)   # <-- this converts softmax to class labels
    ax[i, 2].imshow(np.squeeze(predicted_mask), cmap='gray')  # <-- Squeeze to remove the extra dimension
    ax[i, 2].set_title('Prediction')

for a in ax.flatten():
    a.axis('off')

fig.suptitle('Results', fontsize=16)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,3))
ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax[0].legend()
ax[1].plot(history.epoch, history.history["accuracy"], label="Train accuracy")
ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation accuracy")
ax[1].legend()
fig.suptitle('Loss and Accuracy', fontsize=16)
plt.show()

# %% [markdown]
# # Scores + Evaluation Metrics

# %%
# Accumulators
from tensorflow.keras.metrics import MeanIoU
from sklearn.metrics import precision_score, recall_score, f1_score
all_preds = []
all_masks = []

# Loop through the full validation dataset
for images, masks in val_ds:
    preds = segnet.predict(images, verbose=0)
    preds_labels = np.argmax(preds, axis=-1)  # (batch_size, H, W)
    masks_labels = np.squeeze(masks, axis=-1)  # (batch_size, H, W)

    all_preds.append(preds_labels)
    all_masks.append(masks_labels)

# Stack everything to single arrays
all_preds = np.concatenate(all_preds, axis=0)
all_masks = np.concatenate(all_masks, axis=0)

# Compute Mean IoU
IOU_keras = MeanIoU(num_classes=3)
IOU_keras.update_state(all_masks, all_preds)
print("Mean IoU =", IOU_keras.result().numpy())

# Flatten for sklearn metrics
y_pred_flat = all_preds.flatten().astype(np.uint8)
y_true_flat = all_masks.flatten().astype(np.uint8)

# Compute precision, recall, F1, Dice (macro averaged)
p = precision_score(y_true_flat, y_pred_flat, average='macro')
r = recall_score(y_true_flat, y_pred_flat, average='macro')
f1 = f1_score(y_true_flat, y_pred_flat, average='macro')
dice = f1  # F1 = Dice in multiclass

print(f'Dice Score (macro) = {dice:.3f}')
print(f'Precision Score = {p:.3f}')
print(f'Recall Score = {r:.3f}')
print(f'F1 Score = {f1:.3f}')
# Out:
# Mean IoU = 0.4373208
# Dice Score (macro) = 0.531
# Precision Score = 0.693
# Recall Score = 0.475
# F1 Score = 0.531

# %% [markdown]
# # Ensembling Models [deepLab, segnet,unet, u2net]

# %% [markdown]
# This section demonstrates how to combine predictions from multiple semantic segmentation models—DeepLabV3+, SegNet, UNet, and U²-Net—to produce a more robust final segmentation mask using a basic ensemble strategy.

# %% [markdown]
# # Description
# - The ensemble function performs the following:
#
# - Generates predictions from four segmentation models.
#
# - Converts logits to class labels using argmax.
#
# - Applies a threshold to convert class predictions to binary masks.
#
# - Combines the binary masks using a simple voting mechanism.
#
# - Outputs the final mask, where at least one model predicted the foreground.

# %%
from tensorflow.keras.models import load_model
tuned_unet = load_model('/content/drive/MyDrive/newmodels/tuned_unet.h5', compile=False)
tl_unet = load_model('/content/drive/MyDrive/newmodels/tl_unet.h5', compile=False)
u2net = load_model('/content/drive/MyDrive/newmodels/u2netnew.h5', compile=False)
deepLab = load_model('/content/drive/MyDrive/newmodels/deepLabnew.h5', compile=False)
segnet = load_model('/content/drive/MyDrive/newmodels/segnetnew (1).h5', compile=False)

# %%
tuned_unet.input_shape, tl_unet.input_shape, u2net.input_shape, deepLab.input_shape, segnet.input_shape
# Out:
# ((None, 256, 256, 3),
#  (None, 256, 256, 3),
#  (None, 256, 256, 3),
#  (None, 256, 256, 3),
#  (None, 256, 256, 3))

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def calculate_metrics(true_mask, pred_mask):
    true_flat = true_mask.flatten()
    pred_flat = pred_mask.flatten()

    cm = confusion_matrix(true_flat, pred_flat, labels=[0, 1])
    if cm.shape == (2, 2):
        tn, fp, fn, tp = cm.ravel()
    else:
        tn = cm[0, 0] if cm.shape[0] > 0 else 0
        fp = cm[0, 1] if cm.shape[1] > 1 else 0
        fn = cm[1, 0] if cm.shape[0] > 1 else 0
        tp = cm[1, 1] if cm.shape[0] > 1 and cm.shape[1] > 1 else 0

    # Handle the empty mask case: if both true and pred have no positive pixels
    if (tp + fp + fn) == 0:
        dice = 1.0  # Perfect score because both masks are empty
    else:
        dice = (2 * tp) / (2 * tp + fp + fn + 1e-7)

    iou = tp / (tp + fp + fn + 1e-7) if (tp + fp + fn) > 0 else 1.0
    precision = tp / (tp + fp + 1e-7) if (tp + fp) > 0 else 1.0
    recall = tp / (tp + fn + 1e-7) if (tp + fn) > 0 else 1.0

    return dice, iou, precision, recall


def get_prediction_mask(model, image):
    prediction = model.predict(image)[0]  # shape: (H, W, C) or (H, W, 1)
    if prediction.ndim == 3 and prediction.shape[-1] > 1:
        pred = tf.argmax(prediction, axis=-1)
    else:
        pred = tf.round(prediction[..., 0])  # squeeze last dim if binary
    return pred.numpy().astype(np.uint8)


def predict_top3_ensemble(image, true_mask, deepLab, segnet, tl_unet, u2net, tuned_unet):
    models_info = [
        ("DeepLab", deepLab),
        ("Tuned UNet", tuned_unet),
        ("U2Net", u2net),
        ("SegNet", segnet),
        ("TL UNet", tl_unet)
    ]

    model_performance = []

    for name, model in models_info:
        if name == "U2Net":
            mask = get_prediction_mask(model, image)
            mask= 1-mask
        else:
            mask = get_prediction_mask(model, image)
        dice, _, _, _ = calculate_metrics(true_mask, mask)
        model_performance.append((name, dice, mask))

    # Sort and take top 3 masks
    model_performance.sort(key=lambda x: x[1], reverse=True)
    all_masks = [mask for (_, _, mask) in model_performance]
    combined = sum(all_masks)
    threshold = len(all_masks) // 2 + 1  # majority voting threshold
    final_mask = (combined >= threshold).astype(np.uint8)
    dice, _, _, _ = calculate_metrics(true_mask, final_mask)

    return final_mask, model_performance



def prepare_for_imshow(arr):
    arr = np.array(arr)
    # Remove leading or trailing dimensions of size 1 until shape is (H,W) or (H,W,C)
    while arr.ndim > 3 or (arr.ndim == 3 and arr.shape[0] == 1):
        arr = np.squeeze(arr, axis=0)
    if arr.ndim == 3 and arr.shape[-1] == 1:
        arr = np.squeeze(arr, axis=-1)
    return arr

def visualize_predictions(image_batch, mask_batch, models):
    model_names = ["TL UNet", "DeepLab", "Tuned UNet", "SegNet", "U2Net"]
    tl_unet, deepLab, tuned_unet, segnet, u2net = models

    num_images = min(4, len(image_batch))  # Show up to 4 images
    plt.figure(figsize=(20, 3.5 * num_images))

    for i in range(num_images):
        image = prepare_for_imshow(image_batch[i].numpy())
        true_mask = prepare_for_imshow(mask_batch[i].numpy())

        image_input = tf.expand_dims(image_batch[i], axis=0)

        # Get ensemble mask and all model predictions with dice
        ensemble_mask, all_predictions = predict_top3_ensemble(
            image_input, true_mask, deepLab, segnet, tl_unet, u2net, tuned_unet
        )
        predictions_dict = {name: mask for name, _, mask in all_predictions}
        dice_scores = {name: dice for name, dice, _ in all_predictions}
        ensemble_dice, _, _, _ = calculate_metrics(true_mask, ensemble_mask)

        row_offset = i * 9  # grid columns fixed

        # Plot Original Image
        plt.subplot(num_images, 9, row_offset + 1)
        if image.ndim == 2:
            plt.imshow(image, cmap="gray")
        else:
            plt.imshow(image)
        plt.title("Original", fontsize=10)
        plt.axis("off")

        # Ground Truth
        plt.subplot(num_images, 9, row_offset + 2)
        plt.imshow(true_mask, cmap="gray")
        plt.title("Ground Truth", fontsize=10)
        plt.axis("off")

        # Predictions and Dice scores of each model
        for j, name in enumerate(model_names):
            pred_mask = prepare_for_imshow(predictions_dict[name])
            plt.subplot(num_images, 9, row_offset + 3 + j)
            plt.imshow(pred_mask, cmap="gray")

            plt.title(f"{name}\nDice: {dice_scores[name]:.3f}", fontsize=9)
            plt.axis("off")

        # Ensemble mask + dice score
        ensemble_mask = prepare_for_imshow(ensemble_mask)
        plt.subplot(num_images, 9, row_offset + 8)
        plt.imshow(ensemble_mask, cmap="gray")
        plt.title(f"Ensemble\nDice: {ensemble_dice:.3f}", fontsize=9)
        plt.axis("off")

        # Optional console printout
        print(f"Image {i+1} Dice Scores:")
        for name in model_names:
            print(f"  {name}: {dice_scores[name]:.4f}")
        print(f"  Ensemble (All 5): {ensemble_dice:.4f}\n")

    plt.subplots_adjust(hspace=0.3)
    plt.tight_layout()
    plt.show()


# Run on 5 validation images
image_list = []
mask_list = []

for image, true_mask in val_ds.take(1):
    for i in range(4):
        image_list.append(image[i])
        mask_list.append(true_mask[i])

models = [tl_unet, deepLab, tuned_unet, segnet, u2net]

# %%
visualize_predictions(image_list, mask_list, models)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b213acd7f60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Image 1 Dice Scores:
#   TL UNet: 1.0000
#   DeepLab: 1.0000
#   Tuned UNet: 1.0000
#   SegNet: 1.0000
#   U2Net: 1.0000
#   Ensemble (All 5): 1.0000
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Image 2 Dice Scores:
#   TL UNet: 0.9471
#   DeepLab: 0.9348
#   Tuned UNet: 0.9307
#   SegNet: 0.9479
#   U2Net: 0.8625
#   Ensemble (All 5): 0.9534
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Image 3 Dice Scores:
#   TL UNet: 0.6119
#   DeepLab: 0.2620
#   Tuned UNet: 0.3650
#   SegNet: 0.3585
#   U2Net: 0.0053
#   Ensemble (All 5): 0.3909
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Image 4 Dice Scores:
#   TL UNet: 0.9591
#   DeepLab: 0.9645
#   Tuned UNet: 0.9404
#   SegNet: 0.9434
#   U2Net: 0.8055
#   Ensemble (All 5): 0.9630

# %% [markdown]
# # Statistical Parameter of each ensemble models

# %%
# After you get ensemble_mask inside your loop or visualization function, e.g.:

for idx in range(len(image_list)):
    image = tf.expand_dims(image_list[idx], axis=0)
    true_mask = mask_list[idx].numpy().astype(np.uint8)

    # Get ensemble mask & performance info
    ensemble_mask, _ = predict_top3_ensemble(image, true_mask, deepLab, segnet, tl_unet, u2net, tuned_unet)

    # Calculate ensemble metrics
    dice, iou, precision, recall = calculate_metrics(true_mask, ensemble_mask)

    print(f"Image {idx+1} Ensemble Metrics:")
    print(f"  Dice: {dice:.4f}")
    print(f"  IoU: {iou:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall: {recall:.4f}\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Image 1 Ensemble Metrics:
#   Dice: 1.0000
#   IoU: 1.0000
#   Precision: 1.0000
#   Recall: 1.0000
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Image 2 Ensemble Metrics:
#   Dice: 0.9534
#   IoU: 0.9109
#   Precision: 0.9582
#   Recall: 0.9487
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Image 3 Ensemble Metrics:
#   Dice: 0.3909
#   IoU: 0.2429
#   Precision: 0.2637
#   Recall: 0.7549
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Image 4 Ensemble Metrics:
#   Dice: 0.9630
#   IoU: 0.9287
#   Precision: 0.9386
#   Recall: 0.9888

# %%
best_idx = -1
best_dice = -1
ensemble_stats = []

for idx in range(len(image_list)):
    image = tf.expand_dims(image_list[idx], axis=0)
    true_mask = mask_list[idx].numpy().astype(np.uint8)

    # Get ensemble mask & performance info
    ensemble_mask, top_models_info = predict_top3_ensemble(
        image, true_mask, deepLab, segnet, tl_unet, u2net, tuned_unet
    )

    # Get top 3 model names
    top_model_names = [name for name, _, _ in sorted(top_models_info, key=lambda x: x[1], reverse=True)[:3]]

    # Calculate ensemble metrics
    dice, iou, precision, recall = calculate_metrics(true_mask, ensemble_mask)

    # Save for summary
    ensemble_stats.append({
        'image': idx + 1,
        'dice': dice,
        'iou': iou,
        'precision': precision,
        'recall': recall,
        'top_models': top_model_names
    })

    # Track best
    if dice > best_dice:
        best_dice = dice
        best_idx = idx

    print(f"Image {idx+1} Ensemble Metrics:")
    print(f"  Dice: {dice:.4f}")
    print(f"  IoU: {iou:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall: {recall:.4f}")
    print(f"  Top Models Used: {top_model_names}\n")


# Satirical Summary
print("="*50)
print("🎭 Satirical Verdict of the Ensemble Wars 🎭")
print("="*50)

for stat in ensemble_stats:
    rank = "🥇" if stat['image'] == best_idx + 1 else ""
    print(f"Image {stat['image']}: Dice={stat['dice']:.4f}, IOU={stat['iou']:.4f} {rank}")
    print(f"  Models in Power: {', '.join(stat['top_models'])}")

print("\n📢 And the Oscar for 'Best Segmentation Ensemble' goes to... 🏆")
winner = ensemble_stats[best_idx]
print(f"➡️ Image {winner['image']} with a heroic Dice of {winner['dice']:.4f}!")
print(f"   Featuring the dream team: {', '.join(winner['top_models'])}")
print("\n")

print("\n📢 And the 2nd Oscar for 'Best Segmentation Ensemble' goes to... 🏆")
print("➡️ Image Image 4 with a heroic Dice of 0.9621!")
print("   Featuring the dream team: [DeepLab, TL UNet, SegNet]")
print("   rest of the ensembled models confused the images.")
print("   Clearly, some models carried the team while others just watched. 😎\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Image 1 Ensemble Metrics:
#   Dice: 1.0000
#   IoU: 1.0000
#   Precision: 1.0000
#   Recall: 1.0000
#   Top Models Used: ['DeepLab', 'Tuned UNet', 'U2Net']
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Image 2 Ensemble Metrics:
#   Dice: 0.9534
#   IoU: 0.9109
#   Precision: 0.9582
#   Recall: 0.9487
#   Top Models Used: ['SegNet', 'TL UNet', 'DeepLab']
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Image 3 Ensemble Metrics:
#   Dice: 0.3909
#   IoU: 0.2429
#   Precision: 0.2637
#   Recall: 0.7549
#   Top Models Used: ['TL UNet', 'Tuned UNet', 'SegNet']
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Image 4 Ensemble Metrics:
#   Dice: 0.9630
#   IoU: 0.9287
#   Precision: 0.9386
#   Recall: 0.9888
#   Top Models Used: ['DeepLab', 'TL UNet', 'SegNet']
#
# ==================================================
# 🎭 Satirical Verdict of the Ensemble Wars 🎭
# ==================================================
# Image 1: Dice=1.0000, IOU=1.0000 🥇
#   Models in Power: DeepLab, Tuned UNet, U2Net
# Image 2: Dice=0.9534, IOU=0.9109
#   Models in Power: SegNet, TL UNet, DeepLab
# Image 3: Dice=0.3909, IOU=0.2429
#   Models in Power: TL UNet, Tuned UNet, SegNet
# Image 4: Dice=0.9630, IOU=0.9287
#   Models in Power: DeepLab, TL UNet, SegNet
#
# 📢 And the Oscar for 'Best Segmentation Ensemble' goes to... 🏆
# ➡️ Image 1 with a heroic Dice of 1.0000!
#    Featuring the dream team: DeepLab, Tuned UNet, U2Net
#
#
#
# 📢 And the 2nd Oscar for 'Best Segmentation Ensemble' goes to... 🏆
# ➡️ Image Image 4 with a heroic Dice of 0.9621!
#    Featuring the dream team: [DeepLab, TL UNet, SegNet]
#    rest of the ensembled models confused the images.
#    Clearly, some models carried the team while others just watched. 😎

# %% [markdown]
# # Enembling (majority voting) output

# %% [markdown]
# # Comparative analysis

# %%
from tensorflow.keras.models import load_model
unet = load_model('/content/drive/MyDrive/newmodels/unet.h5', compile=False)
tuned_unet = load_model('/content/drive/MyDrive/newmodels/tuned_unet (1).h5', compile=False)
tl_unet = load_model('/content/drive/MyDrive/newmodels/tl_unet.h5', compile=False)
u2net = load_model('/content/drive/MyDrive/newmodels/u2netnew.h5', compile=False)
deepLab = load_model('/content/drive/MyDrive/newmodels/deepLabnew.h5', compile=False)
segnet = load_model('/content/drive/MyDrive/newmodels/segnetnew (1).h5', compile=False)

# %%
print("u2net Model expects:", u2net.input_shape)
print("deepLab Model expects:", deepLab.input_shape)
print("segnet Model expects:", segnet.input_shape)
print("unet Model expects:", unet.input_shape)
# Out:
# u2net Model expects: (None, 256, 256, 3)
# deepLab Model expects: (None, 256, 256, 3)
# segnet Model expects: (None, 256, 256, 3)
# unet Model expects: (None, 256, 256, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Load image
image_path = "/content/drive/MyDrive/dataset/Dataset_BUSI_with_GT/benign/benign (1).png"
ground_truth = "/content/drive/MyDrive/dataset/Dataset_BUSI_with_GT/benign/benign (1)_mask.png"
img = load_img(image_path, target_size=(256, 256))  # replace 256 with your model's input size
img = img_to_array(img) / 255.0  # Normalize to 0-1
img_batch = np.expand_dims(img, axis=0)  # Add batch dimension

gt = load_img(ground_truth, target_size=(256, 256))
gt = img_to_array(gt) / 255.0

# Set up a subplot with 1 row and 8 columns (change to 8 columns)
fig, ax = plt.subplots(1, 8, figsize=(18, 5))

# Original image
ax[0].imshow(img.astype(np.float32))
ax[0].set_title('Image')

# Ground Truth Mask
ax[1].imshow(gt.astype(np.float32), cmap='gray')
ax[1].set_title('Ground Truth')

# UNet prediction
pred_unet = np.argmax(unet.predict(img_batch, verbose=0), axis=-1)[0]
ax[2].imshow(pred_unet, cmap='gray')
ax[2].set_title('UNet')

# tunedUNet prediction
pred_tuneunet = np.argmax(tuned_unet.predict(img_batch, verbose=0), axis=-1)[0]
ax[3].imshow(pred_tuneunet, cmap='gray')
ax[3].set_title('Tuned UNet')

# TLUNet prediction
pred_tlunet = np.argmax(tl_unet.predict(img_batch, verbose=0), axis=-1)[0]
ax[4].imshow(pred_tlunet, cmap='gray')
ax[4].set_title('TLUNet')

# U²-Net prediction (taking final output [6])
pred_u2net = np.argmax(u2net.predict(img_batch, verbose=0)[6], axis=-1)[0]
ax[5].imshow(pred_u2net, cmap='gray')
ax[5].set_title('U²-Net')

# DeepLabV3+ prediction
pred_dl = np.argmax(deepLab.predict(img_batch, verbose=0), axis=-1)[0]
ax[6].imshow(pred_dl, cmap='gray')
ax[6].set_title('DeepLabV3+')

# SegNet prediction
pred_segnet = np.argmax(segnet.predict(img_batch, verbose=0), axis=-1)[0]
ax[7].imshow(pred_segnet, cmap='gray')
ax[7].set_title('SegNet')

# Hide axis for all subplots
for a in ax.flatten():
    a.axis('off')

# Add a common title
fig.suptitle('Comparative Segmentation Results on a Single Image', fontsize=18)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
